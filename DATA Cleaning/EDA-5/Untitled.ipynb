# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("D:\Data-Science\DATA Cleaning\EDA-5\mobiles1.csv")

# %%
df.head()
# Out:
#             battery                                     camera  \
# 0  5000 mAh Battery              12MP + 2MP | 8MP Front Camera
# 1  5000 mAh Battery  12MP + 8MP + 2MP + 2MP | 8MP Front Camera
# 2  5000 mAh Battery  12MP + 8MP + 2MP + 2MP | 8MP Front Camera
# 3  5000 mAh Battery  12MP + 8MP + 2MP + 2MP | 8MP Front Camera
# 4  4000 mAh Battery              13MP + 2MP | 5MP Front Camera
#
#                             display  \
# 0   15.8 cm (6.22 inch) HD+ Display
# 1  16.56 cm (6.52 inch) HD+ Display
# 2  16.56 cm (6.52 inch) HD+ Display
# 3  16.56 cm (6.52 inch) HD+ Display
# 4   15.49 cm (6.1 inch) HD+ Display
#
#                                           memory  \
# 0  4 GB RAM | 64 GB ROM | Expandable Upto 512 GB
# 1                           4 GB RAM | 64 GB ROM
# 2                          4 GB RAM | 128 GB ROM
# 3                          4 GB RAM | 128 GB ROM
# 4  3 GB RAM | 32 GB ROM | Expandable Upto 256 GB
#
#                                name  price  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 984 entries, 0 to 983
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   battery    984 non-null    object
#  1   camera     984 non-null    object
#  2   display    984 non-null    object
#  3   memory     984 non-null    object
#  4   name       984 non-null    object
#  5   price      984 non-null    int64
#  6   processor  983 non-null    object
#  7   rating     971 non-null    float64
#  8   reviews    971 non-null    object
#  9   warranty   836 non-null    object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 77.0+ KB

# %%
df.isnull().sum()
# Out:
# battery        0
# camera         0
# display        0
# memory         0
# name           0
# price          0
# processor      1
# rating        13
# reviews       13
# warranty     148
# dtype: int64

# %% [markdown]
# #### 1. Processor have only 1 Missing value this is not big problem
# #### 2. Rating and Review both have 13 missing values it shows that product is newely launch or this product maty not that much populer
# #### 3. Warranty have large missing values it shows it may be and entry issue or warranty may not provided by product this may effect on customer trust

# %%
df["processor"]=df["processor"].fillna(df["processor"].mode()[0])

# %%
df["rating"]=df["rating"].fillna(0)
df["reviews"]=df["reviews"].fillna(0)

# %%
df["warranty"]=df["warranty"].fillna("No waranty")

# %%
df.isnull().sum()
# Out:
# battery      0
# camera       0
# display      0
# memory       0
# name         0
# price        0
# processor    0
# rating       0
# reviews      0
# warranty     0
# dtype: int64

# %%
sns.histplot(df["price"],bins=20,kde=True)
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %% [markdown]
# ### Majority of products fall in mid range it shows in this range there is high compitation

# %%
sns.scatterplot(x="price",y="rating",data=df)
# Out:
# <Axes: xlabel='price', ylabel='rating'>

# %% [markdown]
# ### High price does not always satiesfy customer
