# %% [markdown]
# # Feature Selection- Dropping constant features
#
# In this step we will be removing the features which have constant features which are actually not important for solving the
# problem statement

# %%
import pandas as pd

# Make dataframe of given data
data =pd.DataFrame({
    "A":[1,2,3,4,5],
    "B":[4,6,4,7,9],
    "C":[0,0,0,0,0],
    "D":[1,1,1,1,1]
})

# %%
data.head()
# Out:
#    A  B  C  D
# 0  1  4  0  1
# 1  2  6  0  1
# 2  3  4  0  1
# 3  4  7  0  1
# 4  5  9  0  1

# %% [markdown]
# # Varience Threshold
# Variance Threshold is a feature-selection method.
#
# It is used to remove useless columns from the feature matrix.
#
# It has nothing to do with the target variable.
#
# 1) What it actually checks
#
# Variance =“How much does a feature change across all rows?”
#
# If a column has almost the same value everywhere, it contains no information for learning.
#
# 1. If threshold = 0
# → remove columns with zero variance
#
# 2. If threshold = 0.01
# → remove columns with very little change

# %%
# It remove zero varience feature
from sklearn.feature_selection import VarianceThreshold as vt
var_thr=vt(threshold=0)
var_thr.fit(data)
# Out:
# VarianceThreshold(threshold=0)

# %%
var_thr.get
