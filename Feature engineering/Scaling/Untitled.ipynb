# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Visadataset.csv")

# %% [markdown]
# # Z- score

# %% [markdown]
# #### step-1: read the prevailaing wage data : wage_data(X)
# #### step-2: calculate mean
# #### step-3: calculated std
# #### step-4: Nr= s1-s2
# #### step-5: Nr/s3
#
# I

# %%
wage_data=df["prevailing_wage"]

# %%
mean=s1.mean()

# %%
std=s1.std()

# %%
nr=wage_data-mean

# %%
z_wage=nr/std

# %%
z_wage
# Out:
# 0       -1.398510
# 1        0.169832
# 2        0.919060
# 3        0.169991
# 4        1.428576
#            ...
# 25475    0.049923
# 25476    3.876083
# 25477    1.360253
# 25478    0.221504
# 25479   -0.067762
# Name: prevailing_wage, Length: 25480, dtype: float64

# %%
plt.subplot(1,2,1)
plt.title("Z_wage")
sns.histplot(z_wage,kde=True)
plt.subplot(1,2,2)
sns.histplot(df["prevailing_wage"],kde=True,color='red')
# Out:
# <Axes: xlabel='prevailing_wage', ylabel='Count'>

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler=MinMaxScaler()

# %%
scaler.fit_transform(df[["prevailing_wage"]])
# Out:
# array([[0.00184853],
#        [0.2613452 ],
#        [0.385312  ],
#        ...,
#        [0.45831136],
#        [0.26989486],
#        [0.22203311]], shape=(25480, 1))
