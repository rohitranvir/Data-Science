# %%
from sklearn.preprocessing import OneHotEncoder

# %% [markdown]
# # OneHotEncoder Means One on and one of
#
# #### More labels == More Dimensions == More Process The Data == More time and More memory

# %% [markdown]
# # Relationships
# 1) X1 with X1 = Auto Correlation
# 2) X1 with X2 = Multi collinerality
# 3) X1 with y  = Correllation

# %%
WE DONT WANT RELATION BETWEEN TWO INPUT
                  |
COLUMNS
                  |
THE TWO COLUMNS SHOULD BE INDEPENDENT EACH OTHER
                  |
PERPENDICULAR
                  |
90 DEGREES PHASE SHIFT
                  |
COS AND Sin 90
COS 90 = SIN 0
COS 0=SIN 90
                  |
Orthogonality
                  |
1===0
