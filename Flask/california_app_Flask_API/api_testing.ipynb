# %% [markdown]
# - Rule-1:  Make sure URL should hit on webpage
#
# - Assume that we hit the url
#
# - Assume that we dont have post man
#
# - Then we can test url using python code also
#
# - which url we need to test and what are the arguments for those

# %%
import requests

url = "http://127.0.0.1:8000/predict"

params = {
    "MedInc": 5.0,
    "HouseAge": 20,
    "AveRooms": 6.5,
    "Population": 300,
    "AveOccup": 3,
    "Latitude": 34.05
}


response = requests.get(url, params=params)

# Print JSON response
print(response.json())
# Out:
# {'prediction': 13.23483061629418}
