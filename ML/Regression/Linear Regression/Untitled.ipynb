# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
# %matplotlib inline

# %%
df=pd.read_csv('canada_per_capita_income.csv')
df['per_capita_income']=df['per capita income (US$)']
df.head()
# Out:
#    year  per capita income (US$)  per_capita_income
# 0  1970              3399.299037        3399.299037
# 1  1971              3768.297935        3768.297935
# 2  1972              4251.175484        4251.175484
# 3  1973              4804.463248        4804.463248
# 4  1974              5576.514583        5576.514583

# %%
df.drop('per capita income (US$)',axis=1,inplace=True)

# %%
plt.xlabel('year')
plt.ylabel('per_capita_income')
plt.scatter(df.year,df.per_capita_income,color='red',marker='+')

# %%
reg=linear_model.LinearRegression()

# %%
reg.fit(df[['year']],df.per_capita_income)
# Out:
# LinearRegression()

# %%
reg.predict([[1982]])
# Out:
# C:\Users\rohit\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([9807.02123595])
