# %% [markdown]
# # Histogram plot

# %%
import matplotlib.pyplot as plt
import numpy as np
import random 
x=np.random.randint(10,60,(50))
print(x)
plt.
# Out:
# [11 42 35 38 33 15 51 56 23 11 12 51 42 40 27 30 32 28 17 14 50 58 59 52
#  20 17 13 18 23 33 25 21 56 25 33 29 13 25 16 24 36 48 25 14 59 16 19 16
#  15 16]

# %%
no=[11 ,42, 35, 38 ,33 ,15, 51, 56, 23, 11, 12, 51, 42, 40, 27, 30, 32, 28, 17, 14, 50, 58, 59, 52,
 20, 17, 13, 18, 23, 33, 25, 21, 56, 25, 33, 29, 13, 25, 16, 24, 36, 48, 25, 14, 59, 16, 19, 16,
 15, 16]
l=[10,20,30,40,50,60]
plt.hist(no,color='g',edgecolor='r',width=3,range=(0,100),bottom=10)
plt.title('Rohit')
plt.xlabel('Number')
plt.ylabel('Python')
# Out:
# Text(0, 0.5, 'Python')
