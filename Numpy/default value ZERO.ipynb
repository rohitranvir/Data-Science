# %%
import numpy as np
numpy_array=np.zeros((3,3))
print(numpy_array)
# Out:
# [[0. 0. 0.]
#  [0. 0. 0.]
#  [0. 0. 0.]]

# %%
import numpy as np
arr=np.zeros((2,3), dtype=float)
print(arr)
# Out:
# [[0. 0. 0.]
#  [0. 0. 0.]]

# %%
import numpy as no
arr=np.ones((2,3), dtype=str)
print(arr)
# Out:
# [['1' '1' '1']
#  ['1' '1' '1']]

# %%
import numpy as np
arr=np.empty((2,2))
print(arr)
# Out:
# [[0.00000000e+000 9.56845419e-312]
#  [9.56845418e-312 9.56845417e-312]]

# %%
import numpy as np
arr=np.arange(0,10,2)
print(arr)
arr1=np.arange(10,-10,-2)
print(arr1)
# Out:
# [0 2 4 6 8]
# [10  8  6  4  2  0 -2 -4 -6 -8]

# %%
import numpy as np
arr=np.linspace(0,1,5)
print(arr)
# Out:
# [0.   0.25 0.5  0.75 1.  ]

# %%
import numpy as np
arr=np.full((2,3),2)
print(arr)
# Out:
# [[2 2 2]
#  [2 2 2]]

# %%
import numpy as np
arr=np.eye(3)
print(arr)
# Out:
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
