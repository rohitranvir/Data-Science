# %%
import numpy as np
once=np.ones((2,3))
print(once)
# Out:
# [[1. 1. 1.]
#  [1. 1. 1.]]

# %% [markdown]
# Why this is used
#
# Used for:
#
# bias initialization
#
# normalization baselines
#
# testing array operations
#
# Reality / limitation
#
# Same memory cost as zeros()
#
# Rarely used as final data
#
# Mostly useful for math and testing
