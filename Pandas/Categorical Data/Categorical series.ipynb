# %%
import pandas as pd
data={
    "city":["Pune","Kali","yavatmal","Pusad"],
    "salary":[3000,5000,4000,6000]
}
df=pd.DataFrame(data,dtype="category")
print(df.dtypes)
# Out:
# city      category
# salary    category
# dtype: object

# %%
import pandas as pd
data={
    "city":["Pune","Kali","yavatmal","Pusad"],
    "salary":[3000,5000,4000,6000]
}
df["city"]=df["city"].astype("category")
print(df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 6
#       1 import pandas as pd
#       2 data={
#       3     "city":["Pune","Kali","yavatmal","Pusad"],
#       4     "salary":[3000,5000,4000,6000]
#       5 }
# ----> 6 df["city"]=df["city"].astype("category")
#       7 print(df)
#
# AttributeError: 'str' object has no attribute 'astype'
