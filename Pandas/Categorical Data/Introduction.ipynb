# %% [markdown]
# # PANDAS - CATEGORICAL DATA
#
# In this lesson, we will learn how to work with Categorical data in Pandas. It is a Pandas
# data type corresponding to categorical variables in statistics. A categorical variable takes
# on a limited number of possible values. Examples are gender, blood type, country
# affiliation, rating, etc.
#
# Let us see two examples:
# 1. Create Categorical Series in Pandas
# 2. Create Categorical DataFrame in Pandas
