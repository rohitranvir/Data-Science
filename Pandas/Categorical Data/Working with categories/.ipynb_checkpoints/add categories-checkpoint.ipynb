# %% [markdown]
# # I. PANDAS -APPEND NEW CATEGORIES
#
# To append new categories, use the add_categories() method in Python Pandas.
#
# Let us see an example:

# %%
import pandas as pd
s=pd.Series([1,2,3,4],dtype="category")
s=s.cat.add_categories(["R"])
print(s)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: category
# Categories (5, object): [1, 2, 3, 4, 'R']
