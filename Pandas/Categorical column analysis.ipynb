# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data={
    'Regin':['North','South','East','West','North','South','West','North'],
    'Product':['A','A','B','B','A','B','A','B'],
    'Sales':[200,300,150,400,250,100,300,500],
    'Transaction':[2,4,3,5,1,2,6,3]
}
# Total sales per region
# Count of transaction
# Average sales per region
#Total Number of transaction per region

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#    Regin Product  Sales  Transaction
# 0  North       A    200            2
# 1  South       A    300            4
# 2   East       B    150            3
# 3   West       B    400            5
# 4  North       A    250            1
# 5  South       B    100            2
# 6   West       A    300            6
# 7  North       B    500            3

# %%
# Total sales per region
df.groupby()
