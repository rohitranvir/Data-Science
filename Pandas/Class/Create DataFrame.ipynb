# %%
import pandas as pd
import numpy as np
data={
    "Name":["Rohit","Santosh","Ranvir"],
    "Age":[22, 25,23],
    "marks":[25,30,35],  
    "city":['pune','mumbai','delhi']
    
}
df =pd.DataFrame(data)
print("Student Records\n\n", df)
# Out:
# Student Records
#
#        Name  Age  marks    city
# 0    Rohit   22     25    pune
# 1  Santosh   25     30  mumbai
# 2   Ranvir   23     35   delhi

# %% [markdown]
# # I want to drop Column

# %%
# I want to drop marks Column
df.drop("Name",axis=1)
# Out:
#    Age  marks    city
# 0   22     25    pune
# 1   25     30  mumbai
# 2   23     35   delhi

# %%
df.drop('Name',axis=0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[108], line 1
# ----> 1 df.drop('Name',axis=0)
#
# File D:\Data-Science\venv\Lib\site-packages\pandas\core\frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)   5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)   5601             weight  1.0     0.8
#    5602     """
# -> 5603     return super().drop(
#    5604         labels=labels,
#    5605         axis=axis,
#    5606         index=index,
#    5607         columns=columns,
#    5608         level=level,
#    5609         inplace=inplace,
#    5610         errors=errors,
#    5611     )
#
# ...

# %%
df.drop('Name',axis=0,errors = 'ignore')

# %%
df.drop(columns=['Name'])

# %%
df.drop(columns=2)

# %% [markdown]
# # Inplace
# - When we some operation the output will not reflect in origional
# - at the time check the  **inplace** operator
# - if the **inplace =False** the result will not over write
# - make sure inplace=True should be provide , inorder overwrite the output

# %% [markdown]
# # How to  add row
# - loc and iloc operation

# %%
df.loc[2]

# %%
d1={'Name':'Pratham','Age':22,'marks':95,'city':'pune'}

# %%
df.loc[3]=d1

# %%
df
# Out:
#       Name  Age  marks    city
# 0    Rohit   22     25    pune
# 1  Santosh   25     30  mumbai
# 2   Ranvir   23     35   delhi
# 3  Pratham   22     95    pune

# %% [markdown]
# # How to add row at the end

# %%
df.loc[len(df)]=d1={'Name':'Pratham','Age':22,'marks':95,'city':'pune'}

# %% [markdown]
# # How to read a last row when we have large dataset

# %%
df.iloc[len(df)-1]
# Out:
# Name     Pratham
# Age           22
# marks         95
# city        pune
# Name: 4, dtype: object

# %%
df
# Out:
#       Name  Age  marks    city
# 0    Rohit   22     25    pune
# 1  Santosh   25     30  mumbai
# 2   Ranvir   23     35   delhi
# 3  Pratham   22     95    pune
# 4  Pratham   22     95    pune

# %%
df.drop_duplicates()
# Out:
#       Name  Age  marks    city
# 0    Rohit   22     25    pune
# 1  Santosh   25     30  mumbai
# 2   Ranvir   23     35   delhi
# 3  Pratham   22     95    pune

# %%
data={
    "Name":["Rohit","Santosh","Ranvir"],
    "Age":[22, 25,23],
    "marks":[25,30,35],  
    "city":['pune','mumbai','delhi']
    
}
df1=pd.DataFrame(data)

# %%
df1
# Out:
#       Name  Age  marks    city
# 0    Rohit   22     25    pune
# 1  Santosh   25     30  mumbai
# 2   Ranvir   23     35   delhi

# %%
data={
    "Name":["Rohit","Santosh","Ranvir"],
    "Age":[22, 25,23],
    "marks":[25,30,35],  
    "city":['pune','mumbai','delhi']
    
}
df2=pd.DataFrame(df2)

# %%
df2
# Out:
#    surname  values  Random    city
# 0    Rohit      22      25    pune
# 1  Santosh      25      30  mumbai
# 2   Ranvir      23      35   delhi

# %%
df3=pd.concat([df1,df2],ignore_index=True)

# %%
df3
# Out:
#       Name   Age  marks    city  surname  values  Random
# 0    Rohit  22.0   25.0    pune      NaN     NaN     NaN
# 1  Santosh  25.0   30.0  mumbai      NaN     NaN     NaN
# 2   Ranvir  23.0   35.0   delhi      NaN     NaN     NaN
# 3      NaN   NaN    NaN    pune    Rohit    22.0    25.0
# 4      NaN   NaN    NaN  mumbai  Santosh    25.0    30.0
# 5      NaN   NaN    NaN   delhi   Ranvir    23.0    35.0

# %% [markdown]
# # How to rename the Column

# %%
df.rename(columns={'marks':'Percenteges'})
# Out:
#       Name  Age  Percenteges    city
# 0    Rohit   22           25    pune
# 1  Santosh   25           30  mumbai
# 2   Ranvir   23           35   delhi
# 3  Pratham   22           95    pune
# 4  Pratham   22           95    pune

# %%
d={'marks':'percentages'}
df.rename(d,axis=1)
df.rename(d)
df.rename(d,axis=0)
df.rename(index=d)
df.rename(columns=d)
df.drop_duplicates()
# Out:
#       Name  Age  marks    city
# 0    Rohit   22     25    pune
# 1  Santosh   25     30  mumbai
# 2   Ranvir   23     35   delhi
# 3  Pratham   22     95    pune
