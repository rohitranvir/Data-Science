# %% [markdown]
# # Prewalling wave

# %% [markdown]
# - count
# - mean
# - median
# - 25p
# - 50p
# - 75p
# - min
# - max
# - std

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
visa=pd.read_csv(r'Visadataset.csv')

# %%
num_cols=df.select_dtypes(include=['int','float'])

# %%
num_cols
# Out:
#        no_of_employees  yr_of_estab  prevailing_wage
# 0                14513         2007         592.2029
# 1                 2412         2002       83425.6500
# 2                44444         2008      122996.8600
# 3                   98         1897       83434.0300
# 4                 1082         2005      149907.3900
# ...                ...          ...              ...
# 25475             2601         2008       77092.5700
# 25476             3274         2006      279174.7900
# 25477             1121         1910      146298.8500
# 25478             1918         1887       86154.7700
# 25479             3195         1960       70876.9100
#
# [25480 rows x 3 columns]

# %%
df.describe()
# Out:
#        no_of_employees   yr_of_estab  prevailing_wage
# count     25480.000000  25480.000000     25480.000000
# mean       5667.043210   1979.409929     74455.814592
# std       22877.928848     42.366929     52815.942327
# min         -26.000000   1800.000000         2.136700
# 25%        1022.000000   1976.000000     34015.480000
# 50%        2109.000000   1997.000000     70308.210000
# 75%        3504.000000   2005.000000    107735.512500
# max      602069.000000   2016.000000    319210.270000

# %%
count=df['prevailing_wage'].count()
count
# Out:
# np.int64(25480)

# %%
mean=df['prevailing_wage'].mean()
mean
# Out:
# np.float64(74455.81459209183)

# %%
median=df['prevailing_wage'].median()

# %%
min=df['prevailing_wage'].min()

# %%
list1=[]
for i in num_cols:
    count=df[i].count()
    mean=df[i].mean()
    median=df[i].median()
    min=df[i].min()
    max=df[i].max()
    std=np.std(df[i])
    p_25=np.percentile(df[i],25)
    p_50=np.percentile(df[i],50)
    p_75=np.percentile(df[i],75)
    data=[count,mean,median,p_25,p_50,p_75,min,max,std]
    list1.append(data)
idx=['count','mean','median','p_25','p_50','p_75','min','max','std']

# %%
list1
# Out:
# [[np.int64(25480),
#   np.float64(5667.043210361067),
#   np.float64(2109.0),
#   np.float64(1022.0),
#   np.float64(2109.0),
#   np.float64(3504.0),
#   np.int64(-26),
#   np.int64(602069),
#   np.float64(22877.479904380434)],
#  [np.int64(25480),
#   np.float64(1979.409929356358),
#   np.float64(1997.0),
#   np.float64(1976.0),
#   np.float64(1997.0),
#   np.float64(2005.0),
#   np.int64(1800),
#   np.int64(2016),
#   np.float64(42.36609771725251)],
#  [np.int64(25480),
#   np.float64(74455.81459209183),
#   np.float64(70308.20999999999),
#   np.float64(34015.479999999996),
#   np.float64(70308.20999999999),
#   np.float64(107735.51250000001),
#   np.float64(2.1367),
#   np.float64(319210.27),
#   np.float64(52814.90589711416)]]

# %%
df=pd.DataFrame(
    index=num_cols,
    columns=idx
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File D:\Data-Science\venv\Lib\site-packages\pandas\core\indexes\base.py:566, in Index.__new__(cls, data, dtype, copy, name, tupleize_cols)
#     565 try:
# --> 566     arr = sanitize_array(data, None, dtype=dtype, copy=copy)
#     567 except ValueError as err:
#
# File D:\Data-Science\venv\Lib\site-packages\pandas\core\construction.py:656, in sanitize_array(data, index, dtype, copy, allow_2d)
#     654             subarr = maybe_infer_to_datetimelike(subarr)
# --> 656 subarr = _sanitize_ndim(subarr, data, dtype, index, allow_2d=allow_2d)
#     658 if isinstance(subarr, np.ndarray):
#     659     # at this point we should have dtype be None or subarr.dtype == dtype
#
# File D:\Data-Science\venv\Lib\site-packages\pandas\core\construction.py:715, in _sanitize_ndim(result, data, dtype, index, allow_2d)
#     714         return result
# ...

# %%
max=df['prevailing_wage'].max()
max

# %%
std=np.std(df['prevailing_wage'])

# %%
p_25=np.percentile(df['prevailing_wage'],25)
p_25
# Out:
# np.float64(34015.479999999996)

# %%
p_50=np.percentile(df['prevailing_wage'],50)

# %%
p_75=np.percentile(df['prevailing_wage'],75)

# %%
# np.quantile(df['prevailing_wage'],0.25)

# %%
data=[count,mean,median,p_25,p_50,p_75,min,max,std]
idx=['count','mean','median','p_25','p_50','p_75','min','max','std']

# %%
wage_data=pd.DataFrame(
    data=data,
    index=idx,
    columns=['prevailing_wage']
)

# %%
wage_data.mean()==wage_data.median()
# Out:
# np.False_

# %% [markdown]
# - What is mean of False
#    - Data does not follow Normal distribution

# %%
p_25=round(np.percentile(wage_data,25),2)
p_25
# Out:
# np.float64(34015.48)

# %% [markdown]
# - 25 percentage of data less than 34015.48
#
# - How much total data : 25480 applicant
#
# - 25 % of 25480 applicant have salary less than 34015
#
# - m

# %%
con=wage_data<p_25
# df[con]
con
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 25475    False
# 25476    False
# 25477    False
# 25478    False
# 25479    False
# Name: prevailing_wage, Length: 25480, dtype: bool

# %%
df[con]
# Out:
#       case_id continent education_of_employee has_job_experience  \
# 0         NaN       NaN                   NaN                NaN
# 1         NaN       NaN                   NaN                NaN
# 2         NaN       NaN                   NaN                NaN
# 3         NaN       NaN                   NaN                NaN
# 4         NaN       NaN                   NaN                NaN
# ...       ...       ...                   ...                ...
# 25475     NaN       NaN                   NaN                NaN
# 25476     NaN       NaN                   NaN                NaN
# 25477     NaN       NaN                   NaN                NaN
# 25478     NaN       NaN                   NaN                NaN
# 25479     NaN       NaN                   NaN                NaN
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                       NaN              NaN          NaN
# 1                       NaN              NaN          NaN
# ...

# %%
wage_data=df['prevailing_wage']

# %%
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 25475    False
# 25476    False
# 25477    False
# 25478    False
# 25479    False
# Name: prevailing_wage, Length: 25480, dtype: bool

# %% [markdown]
# # Emperical Rule

# %% [markdown]
# u-1*sigma to u+1*sigma===68%
#
# u-2*sigma to u+2*sigma===95%
#
# u-3*sigma to u+3*sigma===99.7%
#
# Step-1=u
#
# Step-2=std
#
# Step-3=lb=u-1*std
#
# Step-4=ub=u+1*std
#
# Step-5=con1=wage_data>lb
#
# Step-6=con2=wage_data<ub
#
# Step-7=con =con1 & con2
#
# Step-8=len(df[con])
#
# Step-9=68%len(df)

# %%
con=wage_data<p_25

# %%
wage_data=df['prevailing_wage']

# %%
df[df['prevailing_wage']<np.percentile(wage_data,25)]
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 0         EZYV01           Asia           High School                  N
# 7         EZYV08  North America            Bachelor's                  Y
# 12        EZYV13           Asia            Bachelor's                  Y
# 16        EZYV17         Europe              Master's                  Y
# 17        EZYV18           Asia              Master's                  Y
# ...          ...            ...                   ...                ...
# 25461  EZYV25462           Asia              Master's                  Y
# 25465  EZYV25466  North America           High School                  N
# 25466  EZYV25467         Europe            Bachelor's                  Y
# 25470  EZYV25471  North America              Master's                  Y
# 25473  EZYV25474           Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %%
wage_data.mean()
# Out:
# np.float64(74455.81459209183)

# %%
visa["prevailing_wage"].mean()
# Out:
# np.float64(74455.81459209183)

# %%
con1 = visa["prevailing_wage"].mean() - visa["prevailing_wage"].std()
con2 = visa["prevailing_wage"].mean() + visa["prevailing_wage"].std()

# %%
visa[(visa["prevailing_wage"] > con1) & (visa["prevailing_wage"] < con2)]
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 5         EZYV06      Asia              Master's                  Y
# 6         EZYV07      Asia            Bachelor's                  N
# ...          ...       ...                   ...                ...
# 25473  EZYV25474      Asia            Bachelor's                  Y
# 25474  EZYV25475    Africa             Doctorate                  N
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 1                         N             2412         2002
# ...

# %%
u=wage_data.mean()
std=wage_data.std()
lb=u-1*std
ub=u+1*std
con1=wage_data>lb
con2=wage_data<ub
con =con1 & con2
len(df[con])
# 68%len(df)
# Out:
# 17171

# %%
u=wage_data.mean()
std=wage_data.std()
for i in range(1,4):

# %%
val=wage_data.values

# %%
plt.hist(wage_data,bins=50)
# plt.show()
# Out:
# (array([2813.,  708.,  725.,  832.,  960.,  993., 1109., 1132., 1108.,
#         1162., 1184., 1154., 1159., 1117., 1067., 1047.,  953.,  955.,
#          816.,  780.,  673.,  539.,  469.,  364.,  289.,  211.,  139.,
#          107.,   81.,   86.,   79.,   87.,   78.,   69.,   60.,   49.,
#           57.,   52.,   45.,   37.,   28.,   27.,   26.,   20.,   13.,
#            4.,    5.,    4.,    4.,    4.]),
#  array([2.13670000e+00, 6.38629937e+03, 1.27704620e+04, 1.91546247e+04,
#         2.55387874e+04, 3.19229500e+04, 3.83071127e+04, 4.46912754e+04,
#         5.10754380e+04, 5.74596007e+04, 6.38437634e+04, 7.02279260e+04,
#         7.66120887e+04, 8.29962514e+04, 8.93804140e+04, 9.57645767e+04,
#         1.02148739e+05, 1.08532902e+05, 1.14917065e+05, 1.21301227e+05,
#         1.27685390e+05, 1.34069553e+05, 1.40453715e+05, 1.46837878e+05,
#         1.53222041e+05, 1.59606203e+05, 1.65990366e+05, 1.72374529e+05,
# ...

# %%
#  there are 2813 applicants are earning salary range
round(2.13670000e+00), round(6.38629937e+03)
# Out:
# (2, 6386)

# %%
u=wage_data.mean()
std=wage_data.std()
lb=2
ub=6386
con1=wage_data>lb
con2=wage_data<ub
con =con1 & con2
len(df[con])
# 68%len(df)
# Out:
# 2813

# %%
visa[(visa["prevailing_wage"]>lb)&(visa["prevailing_wage"]<ub)].shape[0]
# Out:
# 2813

# %%
# from mean-median ,Emperical rule and histogeam we can conclude data does not follow Normality
#

# %%
plt.subplot(1,2,1).boxplot(df['prevailing_wage'],vert=False)
plt.subplot(1,2,2).hist(wage_data,bins=50)
# Out:
# (array([2813.,  708.,  725.,  832.,  960.,  993., 1109., 1132., 1108.,
#         1162., 1184., 1154., 1159., 1117., 1067., 1047.,  953.,  955.,
#          816.,  780.,  673.,  539.,  469.,  364.,  289.,  211.,  139.,
#          107.,   81.,   86.,   79.,   87.,   78.,   69.,   60.,   49.,
#           57.,   52.,   45.,   37.,   28.,   27.,   26.,   20.,   13.,
#            4.,    5.,    4.,    4.,    4.]),
#  array([2.13670000e+00, 6.38629937e+03, 1.27704620e+04, 1.91546247e+04,
#         2.55387874e+04, 3.19229500e+04, 3.83071127e+04, 4.46912754e+04,
#         5.10754380e+04, 5.74596007e+04, 6.38437634e+04, 7.02279260e+04,
#         7.66120887e+04, 8.29962514e+04, 8.93804140e+04, 9.57645767e+04,
#         1.02148739e+05, 1.08532902e+05, 1.14917065e+05, 1.21301227e+05,
#         1.27685390e+05, 1.34069553e+05, 1.40453715e+05, 1.46837878e+05,
#         1.53222041e+05, 1.59606203e+05, 1.65990366e+05, 1.72374529e+05,
# ...
