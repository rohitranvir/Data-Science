# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
visa_df=pd.read_csv(r'Visadataset.csv')

# %%
df=visa_df

# %%
int_cols=df.select_dtypes(include=['int','float'])

# %%
int_cols
# Out:
#        no_of_employees  yr_of_estab  prevailing_wage
# 0                14513         2007         592.2029
# 1                 2412         2002       83425.6500
# 2                44444         2008      122996.8600
# 3                   98         1897       83434.0300
# 4                 1082         2005      149907.3900
# ...                ...          ...              ...
# 25475             2601         2008       77092.5700
# 25476             3274         2006      279174.7900
# 25477             1121         1910      146298.8500
# 25478             1918         1887       86154.7700
# 25479             3195         1960       70876.9100
#
# [25480 rows x 3 columns]

# %%
str_cols=df.select_dtypes(include=['object']).columns

# %%
str_cols
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %% [markdown]
# - task-1 : Education of employee frequency table using condition
# - task-2 : Education of employee frequency table using value conuts
# - task-3 : Educatiion of employee frequency table using group by
# - task-4 : create a new directory called frequency table and save the freq table of Education od employee value counts task

# %% [markdown]
# # Taks 1=>

# %%
keys=df['education_of_employee'].value_counts().keys()

# %%
values=df['education_of_employee'].value_counts().values

# %%
d=pd.DataFrame(zip(keys,values),columns=['Label','No of applicant'])
d.to_csv('education_of_employee.csv',index=False)

# %%
import os
cwd=os.getcwd()

# %%
import os
cwd
folder_name='frequency_table'
new_folder=os.makedirs(folder_name,exist_ok=True)

# %%
new_dir=os.path.join(cwd,folder_name)

# %%
cwd=os.getcwd()

# %%
cwd
# Out:
# 'D:\\Data-Science\\Pandas\\Class'

# %%
# folder_name='frequency_table'
new_folder=os.makedirs(folder_name,exist_ok=True)

# %%
new_dir=os.path.join(cwd,folder_name)

# %%
cwd=os.getcwd()
#############################################
folder_name='frequency_folder'
os.makedirs(folder_name,exist_ok=True)
new_dir=os.path.join(cwd,folder_name)
#############################################
file_path=os.path.join(new_dir,'education_of_employee.csv')

# %%
for i in str_cols:
    cwd=os.getcwd()
    folder_name='frequency_name'
    os.makedirs(folder_name,exist_ok=True)
    new_dir=os.path.join(cwd,folder_name)

# %%
for i in str_cols[1:]:
    keys=df[i].value_counts().keys()
    values=df[i].value_counts().values
    d=pd.DataFrame(zip(keys,values),columns=['labels','no_of_applicants'])
    print(d)
# Out:
#           labels  no_of_applicants
# 0           Asia             16861
# 1         Europe              3732
# 2  North America              3292
# 3  South America               852
# 4         Africa               551
# 5        Oceania               192
#         labels  no_of_applicants
# 0   Bachelor's             10234
# 1     Master's              9634
# 2  High School              3420
# 3    Doctorate              2192
#   labels  no_of_applicants
# 0      Y             14802
# 1      N             10678
#   labels  no_of_applicants
# 0      N             22525
# 1      Y              2955
#       labels  no_of_applicants
# 0  Northeast              7195
# 1      South              7017
# 2       West              6586
# 3    Midwest              4307
# 4     Island               375
#   labels  no_of_applicants
# 0   Year             22962
# 1   Hour              2157
# 2   Week               272
# 3  Month                89
#   labels  no_of_applicants
# ...

# %%
str_cols
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
for i in str_cols[1:]:
    keys=df[i].value_counts().keys()
    values=df[i].value_counts().values
    d=pd.DataFrame(zip(keys,values),columns=['labels','no_of_applicants'])
    # print(d)
    cwd=os.getcwd()
    print(cwd)
    folder_name='frequency_table'
    os.makedirs(folder_name,exist_ok=True)
    
    new_dir=os.path.join(cwd,folder_name)
    path=os.path.join(new_dir,f"{i}.csv")
    print(path)
    d.to_csv(path,index=False)
# Out:
# D:\Data-Science\Pandas\Class
# D:\Data-Science\Pandas\Class\frequency_table\continent.csv
# D:\Data-Science\Pandas\Class
# D:\Data-Science\Pandas\Class\frequency_table\education_of_employee.csv
# D:\Data-Science\Pandas\Class
# D:\Data-Science\Pandas\Class\frequency_table\has_job_experience.csv
# D:\Data-Science\Pandas\Class
# D:\Data-Science\Pandas\Class\frequency_table\requires_job_training.csv
# D:\Data-Science\Pandas\Class
# D:\Data-Science\Pandas\Class\frequency_table\region_of_employment.csv
# D:\Data-Science\Pandas\Class
# D:\Data-Science\Pandas\Class\frequency_table\unit_of_wage.csv
# D:\Data-Science\Pandas\Class
# D:\Data-Science\Pandas\Class\frequency_table\full_time_position.csv
# D:\Data-Science\Pandas\Class
# D:\Data-Science\Pandas\Class\frequency_table\case_status.csv

# %%
keys
# Out:
# Index(['Certified', 'Denied'], dtype='object', name='case_status')

# %% [markdown]
# # Bar Chart
#   - X-axis: class
#   - y-Axis : Number of Applicants

# %%
keys=df['continent'].value_counts().keys()
value=df['continent'].value_counts().values
continent_df=pd.DataFrame(zip(keys,value),columns=['Class','Number of Applicants'])

# %%
value
# Out:
# array([16861,  3732,  3292,   852,   551,   192])

# %%
plt.figure(figsize=(9,3))
col=['Pink','Red','Blue','Green','Orange','Yellow']
plt.bar(keys,value,color=col)
plt.xlabel('Class')
plt.ylabel('Number of applicant')
plt.title('Continent Bar Chart')
plt.show()

# %%
data=pd.read_csv('education_of_employee.csv')
data
# Out:
#          Label  No of applicant
# 0   Bachelor's            10234
# 1     Master's             9634
# 2  High School             3420
# 3    Doctorate             2192

# %%
keys=df['education_of_employee'].value_counts().keys()
value=df['education_of_employee'].value_counts().values

# %%
plt.figure(figsize=(9,3))
plt.bar(keys,value)
plt.title('Education of employee')
plt.xlabel('Degrees')
plt.ylabel('total Employee')
plt.savefig('Education of employee.png')

# %%
for i in str_cols[1:]:
    keys=df[i].value_counts().keys()
    value=df[i].value_counts().values
    plt.figure(figsize=(9,3))
    plt.bar(keys,value)
    plt.title(f'{i}')
    plt.xlabel('Degrees')
    plt.ylabel('total Employee')
    plt.savefig(f'{i}.png')
    plt.show()

# %%
for i in str_cols[1:]:
    keys=df[i].value_counts().keys()
    value=df[i].value_counts().values
    plt.figure(figsize=(9,3))
    plt.bar(keys,value)
    plt.title(i)
    plt.xlabel(i)
    plt.ylabel('total COunt')
    cwd=os.getcwd() 
    folder='Figures'
    os.makedirs(folder,exist_ok=True)
    new_dir=os.path.join(cwd,folder)
    file_path=os.path.join(new_dir,f'{i}.png')
    plt.savefig(file_path)
    plt.show()

# %%
import os
cwd=os.getcwd()
new_folder='Bar_plot'
os.makedirs(new_folder,exist_ok=True)
new_dir=os.path.join(cwd,new_folder)
for i in str_cols[1:]:
    keys=df[i].value_counts().keys()
    value=df[i].value_counts().values
    plt.bar(keys,value)

# %%
sns.countplot(x='continent',data=df)
# Out:
# <Axes: xlabel='continent', ylabel='count'>

# %%
df['continent'].value_counts(normalize=True)*100
# Out:
# continent
# Asia             66.173469
# Europe           14.646782
# North America    12.919937
# South America     3.343799
# Africa            2.162480
# Oceania           0.753532
# Name: proportion, dtype: float64

# %%
keys=df['continent'].value_counts().keys()

# %%
values=df['continent'].value_counts().values

# %%
keys
# Out:
# Index(['Asia', 'Europe', 'North America', 'South America', 'Africa',
#        'Oceania'],
#       dtype='object', name='continent')

# %%
plt.pie(values,labels=keys,autopct='%1.1f%%',startangle=90,explode=[0.1 for i in range(len(values)) ])
plt.show()

# %%
# path=os.path.join(cwd,folder_name)
import os 
folder_name="Piechart"
cwd=os.getcwd()
os.makedirs(folder_name,exist_ok=True)
new_dir=os.path.join(cwd,folder_name)

for i in str_cols[1:]:
    values=df[i].value_counts().values
    key =df[i].value_counts().index
    plt.pie(values,labels = key)
    file_path=os.path.join(new_dir,f"{i}.png")
    plt.savefig(file_path)
plt.show()

# %%
str_cols
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %% [markdown]
# # Subplot

# %%
plt.subplot(2,2,1)
plt.subplot(2,2,2)
plt.subplot(2,2,3)
plt.subplot(2,2,4)
# Out:
# <Axes: >

# %%
import math
cols = 2
# rows = math.ceil(len(str_cols[1:]) / cols)
plt.figure(figsize=(10,10))
for i in range(1,len(str_cols)):
    col=str_cols[i]    
    keys=df[col].value_counts().keys()
    val=df[col].value_counts().values
    plt.subplot(3,3,i).pie(val,labels=keys,autopct="%0.2f%%",startangle=180,radius=1)
plt.show()

# %%
import math
cols = 2
# rows = math.ceil(len(str_cols[1:]) / cols)
plt.figure(figsize=(12,12))
for i in range(1,len(str_cols)):
    col=str_cols[i]    
    keys=df[col].value_counts().keys()
    val=df[col].value_counts().values
    plt.subplot(3,3,i).bar(x=keys,height=val)
plt.show()
