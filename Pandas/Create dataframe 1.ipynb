# %%
import pandas as pd
data={
    "Name":["Rohit","Santosh","Ranvir"],
    "Age":[22, 25,23],
    "Salary":[25000,30000,35000]    
}
df=pd.DataFrame(data,index=['RowA','RowB','RowC'])

print(df.loc['RowA','Name'])
# Out:
# Rohit

# %%
import pandas as pd
data={
    "Name":["Rohit","Santosh","Ranvir"],
    "Age":[22, 25,23],
    "Salary":[25000,30000,35000]    
}
df =pd.DataFrame(data,index=['RowA','RowB','RowC'])
print("Student Records\n\n", df)
for col in df:
    print(col)
# Out:
# Student Records
#
#           Name  Age  Salary
# RowA    Rohit   22   25000
# RowB  Santosh   25   30000
# RowC   Ranvir   23   35000
# Name
# Age
# Salary

# %%
import pandas as pd
import numpy as np
data={
    "Name":["Rohit","Santosh","Ranvir"],
    "Age":[22, 25,23],
    "marks":[25,30,35],  
    "city":['pune','mumbai','delhi']
    
}
df =pd.DataFrame(data,index=['RowA','RowB','RowC'])
print("Student Records\n\n", df)
df.to_excel('Record.xlsx',index=False)
# for col in df:
#     print(col)
# Out:
# Student Records
#
#           Name  Age  marks    city
# RowA    Rohit   22     25    pune
# RowB  Santosh   25     30  mumbai
# RowC   Ranvir   23     35   delhi
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 12
#      10 df =pd.DataFrame(data,index=['RowA','RowB','RowC'])
#      11 print("Student Records\n\n", df)
# ---> 12 df.to_excel('Record.xlsx',index=False)
#      13 # for col in df:
#      14 #     print(col)
#
# File D:\Data-Science\venv\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File D:\Data-Science\venv\Lib\site-packages\pandas\core\generic.py:2439, in NDFrame.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, inf_rep, freeze_panes, storage_options, engine_kwargs)
#    2426 from pandas.io.formats.excel import ExcelFormatter
#    2428 formatter = ExcelFormatter(
#    2429     df,
#    2430     na_rep=na_rep,
#    (...)   2437     inf_rep=inf_rep,
#    2438 )
# -> 2439 formatter.write(
#    2440     excel_writer,
#    2441     sheet_name=sheet_name,
#    2442     startrow=startrow,
#    2443     startcol=startcol,
#    2444     freeze_panes=freeze_panes,
#    2445     engine=engine,
#    2446     storage_options=storage_options,
#    2447     engine_kwargs=engine_kwargs,
#    2448 )
#
# File D:\Data-Science\venv\Lib\site-packages\pandas\io\formats\excel.py:943, in ExcelFormatter.write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options, engine_kwargs)
#     941     need_save = False
#     942 else:
# --> 943     writer = ExcelWriter(
#     944         writer,
#     945         engine=engine,
#     946         storage_options=storage_options,
#     947         engine_kwargs=engine_kwargs,
#     948     )
#     949     need_save = True
#     951 try:
#
# File D:\Data-Science\venv\Lib\site-packages\pandas\io\excel\_openpyxl.py:57, in OpenpyxlWriter.__init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#      44 def __init__(
#      45     self,
#      46     path: FilePath | WriteExcelBuffer | ExcelWriter,
#    (...)     55 ) -> None:
#      56     # Use the openpyxl module as the Excel writer.
# ---> 57     from openpyxl.workbook import Workbook
#      59     engine_kwargs = combine_kwargs(engine_kwargs, kwargs)
#      61     super().__init__(
#      62         path,
#      63         mode=mode,
#    (...)     66         engine_kwargs=engine_kwargs,
#      67     )
#
# ModuleNotFoundError: No module named 'openpyxl'
