# %% [markdown]
# # Step 1 :-  Import the packages

# %%
import pandas as pd    # it  is used to perform database operations
import numpy as np     # it  is used to perform numerical operations
import matplotlib.pyplot as plt  #it  is used to  draw Diagram
import seaborn as sns

# %% [markdown]
#  # Create a data frame using list

# %%
l=['ramesh','suresh','satish']
df=pd.DataFrame(l)

# %%
df
# Out:
#         0
# 0  ramesh
# 1  suresh
# 2  satish

# %%
pd.DataFrame(data,index,columns)
data => Array, List
index => Array, List
columns => Array, List

# %% [markdown]
# #  First way

# %%
l=['ramesh','suresh','satish']
df=pd.DataFrame(l)
df['age']=[10,20,30]

# %%
df
# Out:
#         0  age
# 0  ramesh   10
# 1  suresh   20
# 2  satish   30

# %% [markdown]
# # Second Way

# %%
l=['ramesh','suresh','satish']
age=[10,20,30]
data=zip(l,age)
df=pd.DataFrame(data,columns=['l','age'],index=['a','b','c'])
df
# Out:
#         l  age
# a  ramesh   10
# b  suresh   20
# c  satish   30

# %%
l=['ramesh','suresh','satish']
age=[10,20,30]
data=zip(l,age)
df=pd.DataFrame(data,['a','b','c'],columns=['Names','age'])
df
# Out:
#     Names  age
# a  ramesh   10
# b  suresh   20
# c  satish   30

# %% [markdown]
# # Step-1:add the column name

# %%
l=['ramesh','suresh','satish']
age=[10,20,30]
data=zip(l,age)
df=pd.DataFrame(data,['a','b','c'],columns=['Names','age'])
df
# Out:
#     Names  age
# a  ramesh   10
# b  suresh   20
# c  satish   30

# %%
l=['ramesh','suresh','satish']
age=[10,20,30]
data=zip(l,age)
cols=['Names','age']
df=pd.DataFrame(data,['a','b','c'],columns=cols)
df
# Out:
#     Names  age
# a  ramesh   10
# b  suresh   20
# c  satish   30

# %%
l=['ramesh','suresh','satish']
age=[10,20,30]
city=['pune','mumbai','hydrabad']
data=zip(l,age,city)
cols=['Names','age','city']
df=pd.DataFrame(data,['a','b','c'],columns=cols)
df
# Out:
#     Names  age      city
# a  ramesh   10      pune
# b  suresh   20    mumbai
# c  satish   30  hydrabad

# %% [markdown]
# #  Step No :- 7
# **alredy dataframe availabe we need to add extra columns**

# %%
l=['ramesh','suresh','satish']
age=[10,20,30]
city=['pune','mumbai','hydrabad']
data=zip(l,age,city)
cols=['Names','age','city']
df=pd.DataFrame(data,['a','b','c'],columns=cols)
df['marks']=[10,20,30]

# %%
df
# Out:
#     Names  age      city  marks
# a  ramesh   10      pune     10
# b  suresh   20    mumbai     20
# c  satish   30  hydrabad     30

# %% [markdown]
# - for already existed dataframe the above method
# - if column not availabe it will create  a new column
# - if column already availabe it will update values
# - make sure while crreating or updating values the values should be equal to number of rows

# %% [markdown]
# # Create a empty dataframe and update the values

# %%
# l=['ramesh','suresh','satish']
# age=[10,20,30]
# city=['pune','mumbai','hydrabad']
# data=zip(l,age,city)
cols=['Names','age','city','marks']
df=pd.DataFrame(data,['a','b','c'],columns=cols)
# df['marks']=[10,20,30]

# %%
df['Names']=['ramesh','suresh','satish']
df['age']=[10,20,30]
df['city']=['pune','mumbai','hydrabad']
df['marks']=[10,20,30]

# %%
df
# Out:
#     Names  age      city  marks
# a  ramesh   10      pune     10
# b  suresh   20    mumbai     20
# c  satish   30  hydrabad     30

# %%
data={
    'Names':['ramesh','suresh','satish'],
    'age':[10,20,30],
    'city':['pune',None,'hydrabad'],
    'marks':[10,20,30]
}
df=pd.DataFrame(data,index=['a','b','c'])

# %%
df.isnull().sum()
# Out:
# Names    0
# age      0
# city     0
# marks    0
# dtype: int64

# %%
df['city'].fillna('hydrabad',inplace=True)
# Out:
# C:\Users\rohit\AppData\Local\Temp\ipykernel_19064\3655656848.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['city'].fillna('hydrabad',inplace=True)

# %%
data={
    'Names':'ramesh',
    'age':10,
    'city':'pune',
    'marks':10
}
df=pd.DataFrame(data,index=['a','b','c'])

# %%
df
# Out:
#     Names  age  city  marks
# a  ramesh   10  pune     10
# b  ramesh   10  pune     10
# c  ramesh   10  pune     10

# %%
data={
    'Names':'ramesh',
    'age':10,
    'city':'pune',
    'marks':10
}
df=pd.DataFrame(data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[80], line 7
#       1 data={
#       2     'Names':'ramesh',
#       3     'age':10,
#       4     'city':'pune',
#       5     'marks':10
#       6 }
# ----> 7 df=pd.DataFrame(data)
#
# File D:\Data-Science\venv\Lib\site-packages\pandas\core\frame.py:782, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     776     mgr = self._init_mgr(
#     777         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     778     )
#     780 elif isinstance(data, dict):
#     781     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 782     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     783 elif isinstance(data, ma.MaskedArray):
#     784     from numpy.ma import mrecords
#
# ...

# %%
data={
    'Names':'ramesh',
    'age':10,
    'city':'pune',
    'marks':10
}
df=pd.DataFrame(data,index=['a'])

# %%
df
# Out:
#     Names  age  city  marks
# a  ramesh   10  pune     10

# %% [markdown]
# # Save the DataFrame

# %% [markdown]
# - On what name we want to save   **file Name**
# - At what location we want to save **Directory**
# - Same python location then no need to mention
# - If different from python location then need to provide
# - Extension of the file
#     - .CSV (comma seperated file)
#     - .xlsx (Excel sheet)

# %%
df.to_csv('data.csv',index=False)

# %% [markdown]
# # Step-11: Read the Dataframe

# %%
pd.read_csv('data.csv')
# Out:
#     Names  age  city  marks
# 0  ramesh   10  pune     10
