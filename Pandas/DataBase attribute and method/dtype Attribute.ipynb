# %%
import pandas as pd
data={
    "Students":["Rohit","Santosh","RAnvir"],
    "Rank":[1,2,3],
    "Marks":[95,70,80]
}
df=pd.DataFrame(data,index=["RowA","RowB","RowC"])
print(df.dtypes)
# Out:
# Students    object
# Rank         int64
# Marks        int64
# dtype: object
