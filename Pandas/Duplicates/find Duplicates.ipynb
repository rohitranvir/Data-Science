# %%
import pandas as pd

df = pd.DataFrame({
    "RollNo": [101, 102, 103, 102, 104, 101],
    "Name": ["Rohit", "Amit", "Neha", "Amit", "Vandana", "Rohit"],
    "Marks": [85, 78, 90, 78, 98, 85]
})
print(df.duplicated())
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5     True
# dtype: bool

# %%
import pandas as pd

df = pd.DataFrame({
    "RollNo": [101, 102, 103, 102, 104, 101],
    "Name": ["Rohit", "Amit", "Neha", "Amit", "Vandana", "Rohit"],
    "Marks": [85, 78, 90, 78, 98, 85]
})
print(df[df.duplicated()])
# Out:
#    RollNo   Name  Marks
# 3     102   Amit     78
# 5     101  Rohit     85

# %%
import pandas as pd

df = pd.DataFrame({
    "RollNo": [101, 102, 103, 102, 104, 101],
    "Name": ["Rohit", "Amit", "Neha", "Amit", "Vandana", "Rohit"],
    "Marks": [85, 78, 90, 78, 98, 85]
})
print(df.duplicated(subset=["RollNo"]))
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5     True
# dtype: bool
