# %% [markdown]
# # What does indexing mean?
#
# Indexing means selecting specific data from a table using labels or positions.
#
# In pandas, data is stored in a DataFrame (rows + columns).
# Indexing is the way you pick what you want from that DataFrame.

# %%
import pandas as pd
df=pd.read_csv(r"D:\Data-Science\Pandas\csv\Students.csv")
print(df)
# Out:
#     Students  Rank  Marks
# 0      Rohit     1     95
# 1    Santosh     2     60
# 2     Ranvir     3     50
# 3  Prabhakar     4     80

# %%
import pandas as pd
df=pd.read_csv(r"D:\Data-Science\Pandas\csv\Students.csv")
print(df["Students"])
# Out:
# 0        Rohit
# 1      Santosh
# 2       Ranvir
# 3    Prabhakar
# Name: Students, dtype: object

# %%
import pandas as pd
df=pd.read_csv(r"D:\Data-Science\Pandas\csv\Students.csv")
print(df.iloc[0])
# Out:
# Students    Rohit
# Rank            1
# Marks          95
# Name: 0, dtype: object

# %%
import pandas as pd
df=pd.read_csv(r"D:\Data-Science\Pandas\csv\Students.csv")
print(df.iloc[1])
# Out:
# Students    Santosh
# Rank              2
# Marks            60
# Name: 1, dtype: object

# %%
import pandas as pd
df=pd.read_csv(r"D:\Data-Science\Pandas\csv\Students.csv")
df["Status"] = df["Marks"].apply(
    lambda x: "Pass" if x >= 40 else "Fail"
)

print(df.assign(Result=df["Marks"]>=80))
# Out:
#     Students  Rank  Marks Status  Result
# 0      Rohit     1     95   Pass    True
# 1    Santosh     2     60   Pass   False
# 2     Ranvir     3     50   Pass   False
# 3  Prabhakar     4     80   Pass    True
