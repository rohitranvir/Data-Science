# %%
import pandas as pd
df=pd.read_csv(r"D:\Data-Science\Pandas\csv\Students.csv")
for row in df.iterrows():
    print(row)
    print("\n")
# Out:
# (0, Students    Rohit
# Rank            1
# Marks          95
# Name: 0, dtype: object)
#
#
# (1, Students    Santosh
# Rank              2
# Marks            60
# Name: 1, dtype: object)
#
#
# (2, Students    Ranvir
# Rank             3
# Marks           50
# Name: 2, dtype: object)
#
#
# (3, Students    Prabhakar
# Rank                4
# Marks              80
# Name: 3, dtype: object)

# %%
df=pd.read_csv(r"D:\Data-Science\Pandas\csv\Students.csv")
for row in df.itertuples():
    print(row.Index ,row.Students ,"    ",row.Marks)
# Out:
# 0 Rohit      95
# 1 Santosh      60
# 2 Ranvir      50
# 3 Prabhakar      80
