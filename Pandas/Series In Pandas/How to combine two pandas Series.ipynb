# %% [markdown]
# # COMBINE TWO PANDAS SERIES
#
# To combine two Pandas series into one in Python, use the combine() method. It uses a
# specific function for the decision, mentioned by the user as a parameter of the combine()method.
#
# We will see an example that will fetch the largest values from both series. Each element of
# both the series will be compared one by one. Let us see the example:
