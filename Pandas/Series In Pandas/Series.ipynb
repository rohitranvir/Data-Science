# %% [markdown]
# # WHAT IS A SERIES IN PANDAS ? HOW TO CREATE ?
#
# Series in Pandas is a one-dimensional array, like a column in a table. It is a labeled array
# that can hold data of any type. The Series() method is used for this and has the following
# parameters:
#
# . data: The data to be stored in the Pandas Series
#
# . index: The index values should have the same length as the data.
#
# . dtype: It is the datatype for the output Series.
#
# · name: Set the series name with the name parameter
#
# . copy: To copy the input data
#
# # PANDAS - CREATE A SERIES
#
# In this lesson, we will understand what is Series with the following examples:
# 1. Create a Pandas Series
#
# 2. Access a value from a Pandas Series
#
# 3. Name your own indexes in a Pandas Series
#
# 4. Access a value flom a Pandas Series with labels

# %%
import pandas as pd 
data=[10,20,30,40,50]
s=pd.Series(data,index=["A","B","C","D","E"])
print(s)
print("\n",s["A"])
print("\n",s.iloc[3])
# Out:
# A    10
# B    20
# C    30
# D    40
# E    50
# dtype: int64
#
#  10
#
#  40

# %%
# 1️⃣ From a list
import pandas as pd

s = pd.Series([10, 20, 30])
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
# 2️⃣ From a list with custom index
s = pd.Series([10, 20, 30], index=['a', 'b', 'c'])
print(s)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
# 3️⃣ From a dictionary (very common)
data={"Math":85,"English":20,"Science":65}
s=pd.Series(data)
print(s)
# Out:
# Math       85
# English    20
# Science    65
# dtype: int64

# %%
# Accessing data in a Series
print(s["Math"])
# Out:
# 85

# %%
print(s.iloc[2])
# Out:
# 65

# %%
# Adding Values 
data =[10,20,30]
s=pd.series()
