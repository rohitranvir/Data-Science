# %% [markdown]
# # for sorting by index we have sort_index()

# %%
import pandas as pd
df=pd.read_csv(r"D:\Data-Science\Pandas\csv\Students.csv")
df_sorted=df.sort_index(ascending=False)
print(df_sorted)
# Out:
#     Students  Rank  Marks
# 3  Prabhakar     4     80
# 2     Ranvir     3     50
# 1    Santosh     2     60
# 0      Rohit     1     95
