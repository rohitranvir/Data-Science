# %%
import pandas as pd

df = pd.DataFrame({
    "Name": [" Rohit ", "AMIT", "neha", "San tosh"]
})

print(df["Name"].str.lower())
# Out:
# 0      rohit
# 1        amit
# 2        neha
# 3    san tosh
# Name: Name, dtype: object
