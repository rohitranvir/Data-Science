# %%
import pandas as pd

df = pd.DataFrame({
    "Name": [" Rohit ", "AMIT", "neha", "San tosh"]
})

print(df["Name"].str.title())
# Out:
# 0      Rohit
# 1        Amit
# 2        Neha
# 3    San Tosh
# Name: Name, dtype: object
