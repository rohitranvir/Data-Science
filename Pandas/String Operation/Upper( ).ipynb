# %%
import pandas as pd

df = pd.DataFrame({
    "Name": [" Rohit ", "AMIT", "neha", "San tosh"]
})

print(df["Name"].str.upper())
# Out:
# 0      ROHIT
# 1        AMIT
# 2        NEHA
# 3    SAN TOSH
# Name: Name, dtype: object
