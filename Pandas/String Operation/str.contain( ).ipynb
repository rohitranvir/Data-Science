# %%
import pandas as pd

df = pd.DataFrame({
    "Name": [" Rohit ", "AMIT", "neha", "San tosh"]
})
print(df["Name"].str.contains("Ro",case=True))
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# Name: Name, dtype: bool
