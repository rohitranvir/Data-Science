# %%
import pandas as pd
file=pd.read_csv(r"D:\Data-Science\Pandas\csv\Students.csv",header=None)
print(file)
# Out:
#            0     1      2
# 0   Students  Rank  Marks
# 1      Rohit     1     95
# 2    Santosh     2     60
# 3     Ranvir     3     50
# 4  Prabhakar     4     80
