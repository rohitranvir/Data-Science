# %% [markdown]
# # PANDAS - READ CSV
#
# One of the major benefits of working on Python is the ease to read and access CSV (comma
# separated files). For this, Python is having the Pandas library. In this lesson, we will learn how
# to read CSV in Python Pandas using the read_csv() method.

# %%
import pandas as pd
file=pd.read_csv(r"D:\Data-Science\Pandas\csv\Students.csv",usecols=["Students"],header=None)
print(file)
# Out:
#            0     1      2
# 0   Students  Rank  Marks
# 1      Rohit     1     95
# 2    Santosh     2     60
# 3     Ranvir     3     50
# 4  Prabhakar     4     80
