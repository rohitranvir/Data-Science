# %% [markdown]
# # PANDAS - PLOTTING
#
# To plot in Pandas, we need to use the plot() method and the Matplotlib library. The pyplot
# module from Matplotlib is also used for plotting in Pandas. The pyplot.show() is used to
# display the figure.
# First, install Matplotlib and run your first example:
#
# Example1 Plot a DataFrame in Pandas
#
# Let us now see how to plot:
#
# Example 2: Histogram
#
# Example 3: Pie Chart
#
# Example 4: Scatter Plot
#
# Example 5: Area Plot

# %%
import pandas as pd
import matplotlib.pyplot as plt
data={
    "Temperature":[18,20,22,19,23,24,28,26,17,25],
    "Humidity":[32,31,30,22,17,29,32,37,20,19],
    "Wind":[12,20,8,9,20,27,22,33,37,35],
    "Precipitstion":[17,25,20,19,18,20,28,26,29,22],
    "Name":["Rohit","Santosh","Santosh","Santosh","Santosh","Santosh","Santosh","Santosh","Santosh","Santosh"]
}
df=pd.DataFrame(data)
df.plot()
plt.show()
