# %%
import pandas as pd
df=pd.DataFrame({
    "Name": [" Rohit ", "  Amit", "Neha  ", " San@tosh ", "Va#ndana"]
})
print(df.)
print("\n"df.strip
# Out:
#   Cell In[5], line 5
#     print(df.)
#              ^
# SyntaxError: invalid syntax
