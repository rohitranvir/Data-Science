# %%
import pandas as pd
df=pd.DataFrame({
    "Name": [" Rohit ", "  Amit", "Neha  ", " San@tosh ", "Va#ndana"]
})
print(df["Name"].str.rstrip())
# Out:
# 0        Rohit
# 1         Amit
# 2         Neha
# 3     San@tosh
# 4     Va#ndana
# Name: Name, dtype: object
