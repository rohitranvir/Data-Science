# %%
import pandas as pd
df=pd.DataFrame({
    "Name": [" Rohit ", "  Amit", "Neha  ", " San@tosh ", "Va#ndana"]
})
resdf=df["Name"].str.replace(r"[@#]","",regex=True)

print(resdf)
# Out:
# 0       Rohit
# 1         Amit
# 2       Neha
# 3     Santosh
# 4      Vandana
# Name: Name, dtype: object
