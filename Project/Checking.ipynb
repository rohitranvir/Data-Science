# %%
import pandas as pd
import pickle
model=pickle.load(open("obesity_model.pkl", "rb"))

# %%
input_data = {
    'Screen_time': 1.000000,
    'Weight': 64.000000,
    'consumption_of_vegetables':2.0,
    'Age': 21.000000,
    'Height': 1.620000,
    'Gender': 0
}
user_df=pd.DataFrame([input_data])
prediction=model.predict(user_df)
prediction
# Out:
# array([1])
