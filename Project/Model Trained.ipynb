# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("ObesityDataSet_raw_and_data_sinthetic (1).csv")

# %%
df.head()
# Out:
#    Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 0  Female  21.0    1.62    64.0                            yes   no   2.0
# 1  Female  21.0    1.52    56.0                            yes   no   3.0
# 2    Male  23.0    1.80    77.0                            yes   no   2.0
# 3    Male  27.0    1.80    87.0                             no   no   3.0
# 4    Male  22.0    1.78    89.8                             no   no   2.0
#
#    NCP       CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC  \
# 0  3.0  Sometimes    no   2.0   no  0.0  1.0          no
# 1  3.0  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes
# 2  3.0  Sometimes    no   2.0   no  2.0  1.0  Frequently
# 3  3.0  Sometimes    no   2.0   no  2.0  0.0  Frequently
# 4  1.0  Sometimes    no   2.0   no  0.0  0.0   Sometimes
#
#                   MTRANS           NObeyesdad
# 0  Public_Transportation        Normal_Weight
# 1  Public_Transportation        Normal_Weight
# ...

# %%
df.rename(columns={"FCVC":"consumption_of_vegetables","NCP":"NO_of_main_meals_pr_dy","CAEC":"Food_bet_meals","CH2O":"Water_consumption_ltr","SCC":"Calorie_consump_monitor","FAF":"Physical_acti_pr_week","TUE":"Screen_time","CALC":"Alcohol","MTRANS":"Mod_transportation","NObeyesdad":"Obasity_level"},inplace=True)

# %%
df.head(2)
# Out:
#    Gender   Age  Height  Weight family_history_with_overweight FAVC  \
# 0  Female  21.0    1.62    64.0                            yes   no
# 1  Female  21.0    1.52    56.0                            yes   no
#
#    consumption_of_vegetables  NO_of_main_meals_pr_dy Food_bet_meals SMOKE  \
# 0                        2.0                     3.0      Sometimes    no
# 1                        3.0                     3.0      Sometimes   yes
#
#    Water_consumption_ltr Calorie_consump_monitor  Physical_acti_pr_week  \
# 0                    2.0                      no                    0.0
# 1                    3.0                     yes                    3.0
#
#    Screen_time    Alcohol     Mod_transportation  Obasity_level
# 0          1.0         no  Public_Transportation  Normal_Weight
# 1          0.0  Sometimes  Public_Transportation  Normal_Weight

# %%
df.describe()
# Out:
#                Age       Height       Weight  consumption_of_vegetables  \
# count  2111.000000  2111.000000  2111.000000                2111.000000
# mean     24.312600     1.701677    86.586058                   2.419043
# std       6.345968     0.093305    26.191172                   0.533927
# min      14.000000     1.450000    39.000000                   1.000000
# 25%      19.947192     1.630000    65.473343                   2.000000
# 50%      22.777890     1.700499    83.000000                   2.385502
# 75%      26.000000     1.768464   107.430682                   3.000000
# max      61.000000     1.980000   173.000000                   3.000000
#
#        NO_of_main_meals_pr_dy  Water_consumption_ltr  Physical_acti_pr_week  \
# count             2111.000000            2111.000000            2111.000000
# mean                 2.685628               2.008011               1.010298
# std                  0.778039               0.612953               0.850592
# ...

# %%
df.isnull().sum()
# Out:
# Gender                            0
# Age                               0
# Height                            0
# Weight                            0
# family_history_with_overweight    0
# FAVC                              0
# consumption_of_vegetables         0
# NO_of_main_meals_pr_dy            0
# Food_bet_meals                    0
# SMOKE                             0
# Water_consumption_ltr             0
# Calorie_consump_monitor           0
# Physical_acti_pr_week             0
# Screen_time                       0
# Alcohol                           0
# Mod_transportation                0
# Obasity_level                     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Gender                          2111 non-null   object
#  1   Age                             2111 non-null   float64
#  2   Height                          2111 non-null   float64
#  3   Weight                          2111 non-null   float64
#  4   family_history_with_overweight  2111 non-null   object
#  5   FAVC                            2111 non-null   object
#  6   consumption_of_vegetables       2111 non-null   float64
#  7   NO_of_main_meals_pr_dy          2111 non-null   float64
#  8   Food_bet_meals                  2111 non-null   object
#  9   SMOKE                           2111 non-null   object
#  10  Water_consumption_ltr           2111 non-null   float64
#  11  Calorie_consump_monitor         2111 non-null   object
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(24)

# %%
df
# Out:
#       Gender        Age    Height      Weight family_history_with_overweight  \
# 0     Female  21.000000  1.620000   64.000000                            yes
# 1     Female  21.000000  1.520000   56.000000                            yes
# 2       Male  23.000000  1.800000   77.000000                            yes
# 3       Male  27.000000  1.800000   87.000000                             no
# 4       Male  22.000000  1.780000   89.800000                             no
# ...      ...        ...       ...         ...                            ...
# 2106  Female  20.976842  1.710730  131.408528                            yes
# 2107  Female  21.982942  1.748584  133.742943                            yes
# 2108  Female  22.524036  1.752206  133.689352                            yes
# 2109  Female  24.361936  1.739450  133.346641                            yes
# 2110  Female  23.664709  1.738836  133.472641                            yes
#
# ...

# %%
df=df.drop_duplicates()

# %%
for col in df.select_dtypes(include="object"):
    print(col)
    print(df[col].value_counts())
    print("----------")
# Out:
# Gender
# Gender
# Male      1052
# Female    1035
# Name: count, dtype: int64
# ----------
# family_history_with_overweight
# family_history_with_overweight
# yes    1722
# no      365
# Name: count, dtype: int64
# ----------
# FAVC
# FAVC
# yes    1844
# no      243
# Name: count, dtype: int64
# ----------
# Food_bet_meals
# Food_bet_meals
# Sometimes     1761
# Frequently     236
# Always          53
# no              37
# Name: count, dtype: int64
# ----------
# SMOKE
# SMOKE
# no     2043
# yes      44
# Name: count, dtype: int64
# ----------
# Calorie_consump_monitor
# Calorie_consump_monitor
# no     1991
# yes      96
# Name: count, dtype: int64
# ----------
# Alcohol
# Alcohol
# Sometimes     1380
# no             636
# Frequently      70
# Always           1
# Name: count, dtype: int64
# ----------
# Mod_transportation
# Mod_transportation
# Public_Transportation    1558
# Automobile                456
# Walking                    55
# Motorbike                  11
# ...

# %%
df['Obasity_level'].value_counts()
# Out:
# Obasity_level
# Obesity_Type_I         351
# Obesity_Type_III       324
# Obesity_Type_II        297
# Overweight_Level_II    290
# Normal_Weight          282
# Overweight_Level_I     276
# Insufficient_Weight    267
# Name: count, dtype: int64

# %%
num_cols = df.select_dtypes(include=['float64','int64']).columns

# %%
num_df=df[num_cols]

# %%
for i in num_cols:
    sns.boxplot(x=df[i])
    plt.title(col)
    plt.show()

# %%
sns.heatmap(num_df.corr(), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
from sklearn.preprocessing import LabelEncoder
lr = LabelEncoder()
for col in df.select_dtypes(include='object').columns:
    df[col]=lr.fit_transform(df[col])
# Out:
# C:\Users\rohit\AppData\Local\Temp\ipykernel_16460\2165700909.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col]=lr.fit_transform(df[col])
# C:\Users\rohit\AppData\Local\Temp\ipykernel_16460\2165700909.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col]=lr.fit_transform(df[col])
# C:\Users\rohit\AppData\Local\Temp\ipykernel_16460\2165700909.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df["Obasity_level"].value_counts()
# Out:
# Obasity_level
# 2    351
# 4    324
# 3    297
# 6    290
# 1    282
# 5    276
# 0    267
# Name: count, dtype: int64

# %%
df["Obasity_level"].unique()
# Out:
# array([1, 5, 6, 2, 0, 3, 4])

# %%
x=df.drop('Obasity_level',axis=1)
y=df['Obasity_level']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
rf.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 4
#       1 from sklearn.model_selection import train_test_split
#       3 X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
# ----> 4 rf.fit(X_train, y_train)
#
# NameError: name 'rf' is not defined

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()

# %%
rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
X_train_predicted=rf.predict(X_train)

# %%
accuracy_score(y_train,X_train_predicted)
# Out:
# 1.0

# %%
import numpy as np
input_data = [1,22.0,1.78,89.8,0,0,2.0,1.0,2,0,2.0,0,0.0,0.0,2,3]
# Convert to numpy
input_data_as_np = np.array(input_data, dtype=float)
# Reshape
input_data_reshaped = input_data_as_np.reshape(1, -1)
# If you used scaler during training, apply it here
# input_data_reshaped = scaler.transform(input_data_reshaped)
# Predict
input_data_reshaped = scaler.transform(input_data_reshaped)
prediction = rf.predict(input_data_reshaped)
print(prediction)
# Out:
# [6]
# D:\Data-Science\venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
print(np.unique(y))
print(rf.score(X_test, y_test))
# Out:
# [0 1 2 3 4 5 6]
# 0.9569377990430622

# %%
from sklearn.metrics import accuracy_score
accuracy=accuracy_score(y_test,y_pred)
print("Accuracy : ",accuracy*100)
# Out:
# Accuracy :  11.722488038277511

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.11      0.10      0.11        59
#            1       0.11      0.10      0.10        61
#            2       0.07      0.07      0.07        70
#            3       0.15      0.14      0.15        64
#            4       0.17      0.18      0.18        60
#            5       0.15      0.15      0.15        55
#            6       0.07      0.08      0.07        49
#
#     accuracy                           0.12       418
#    macro avg       0.12      0.12      0.12       418
# weighted avg       0.12      0.12      0.12       418

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(6,4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
importances = pd.Series(rf.feature_importances_, index=x.columns)
print(importances.sort_values(ascending=False))
# Out:
# Screen_time                       0.444284
# Weight                            0.233548
# consumption_of_vegetables         0.058421
# Age                               0.044599
# Height                            0.043884
# Gender                            0.034696
# NO_of_main_meals_pr_dy            0.026162
# family_history_with_overweight    0.026005
# Food_bet_meals                    0.017837
# Physical_acti_pr_week             0.017689
# Water_consumption_ltr             0.016866
# Alcohol                           0.014595
# Mod_transportation                0.009320
# FAVC                              0.009134
# Calorie_consump_monitor           0.002299
# SMOKE                             0.000664
# dtype: float64

# %%
RandomForestClassifier(n_estimators=500)
# Out:
# RandomForestClassifier(n_estimators=500)

# %%
print("Train accuracy:", rf.score(X_train, y_train))
print("Test accuracy:", rf.score(X_test, y_test))
# Out:
# Train accuracy: 1.0
# Test accuracy: 1.0

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(rf, x, y, cv=5)
print(scores)
print("Mean CV accuracy:", scores.mean())
# Out:
# [0.9784689 1.        1.        1.        1.       ]
# Mean CV accuracy: 0.9956937799043063

# %%
import pandas as pd

importances = pd.Series(rf.feature_importances_, index=x.columns)
print(importances.sort_values(ascending=False))
# Out:
# Screen_time                       0.444284
# Weight                            0.233548
# consumption_of_vegetables         0.058421
# Age                               0.044599
# Height                            0.043884
# Gender                            0.034696
# NO_of_main_meals_pr_dy            0.026162
# family_history_with_overweight    0.026005
# Food_bet_meals                    0.017837
# Physical_acti_pr_week             0.017689
# Water_consumption_ltr             0.016866
# Alcohol                           0.014595
# Mod_transportation                0.009320
# FAVC                              0.009134
# Calorie_consump_monitor           0.002299
# SMOKE                             0.000664
# dtype: float64

# %%
inp_feature=["Screen_time","Weight","consumption_of_vegetables","Age","Height","Gender"]

# %%
X_new=df[inp_feature]
y=df["Obasity_level"]

# %%
X_new
# Out:
#       Screen_time      Weight  consumption_of_vegetables        Age    Height  \
# 0        1.000000   64.000000                        2.0  21.000000  1.620000
# 1        0.000000   56.000000                        3.0  21.000000  1.520000
# 2        1.000000   77.000000                        2.0  23.000000  1.800000
# 3        0.000000   87.000000                        3.0  27.000000  1.800000
# 4        0.000000   89.800000                        2.0  22.000000  1.780000
# ...           ...         ...                        ...        ...       ...
# 2106     0.906247  131.408528                        3.0  20.976842  1.710730
# 2107     0.599270  133.742943                        3.0  21.982942  1.748584
# 2108     0.646288  133.689352                        3.0  22.524036  1.752206
# 2109     0.586035  133.346641                        3.0  24.361936  1.739450
# 2110     0.714137  133.472641                        3.0  23.664709  1.738836
#
#       Gender
# 0          0
# ...

# %%
y
# Out:
# 0       1
# 1       1
# 2       1
# 3       5
# 4       6
#        ..
# 2106    4
# 2107    4
# 2108    4
# 2109    4
# 2110    4
# Name: Obasity_level, Length: 2087, dtype: int64

# %%
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier
rf_new=RandomForestClassifier()

# %%
X_train,X_test,y_train,y_test=train_test_split(X_new,y,test_size=0.2, random_state=42, stratify=y)

# %%
rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
X_train_predicted=rf.predict(X_train)

# %%
accuracy_score(y_train,X_train_predicted)
# Out:
# 1.0

# %%
import numpy as np

# %%
input_data=[1.000000,	64.000000,	2.0,	21.000000,	1.620000,	0]
input_data_as_arry=np.asarray(input_data,dtype="float")
input_data_reshaped=input_data_as_arry.reshape(1,-1)
prediction=rf.predict(input_data_reshaped)
print(prediction)
# Out:
# [1]
# D:\Data-Science\venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
import pickle
pickle.dump(rf, open("obesity_model.pkl", "wb"))
pickle.dump(inp_feature, open("features.pkl", "wb"))
