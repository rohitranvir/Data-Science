# %%
def fun(s):

    l=s.split()
    # for i in range(len(s)):
    s1=""
    for i in range(len(l)):
        if i%2==0:
            s1+=(l[i][::-1])
            s1+=" "
        else:
            s1+=l[i]
            s1+=" "
            
    print(s1)
    
s="Rohit vandana santosh prabhakar ranvir"
fun(s)
# Out:
# tihoR vandana hsotnas prabhakar rivnar
