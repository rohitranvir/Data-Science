# %%
import random
def buble_sort(l):
    for i in range(len(l)-1):
        for j in range(len(l)-i-1):
            if l[j]>l[j+1]:
                l[j],l[j+1]=l[j+1],l[j]
    return l
l=[]
for i in range(10):
    l.append(random.randint(100,999))
print(l)
buble_sort(l)
# Out:
# [203, 584, 182, 661, 702, 795, 761, 678, 956, 879]
# [182, 203, 584, 661, 678, 702, 761, 795, 879, 956]
