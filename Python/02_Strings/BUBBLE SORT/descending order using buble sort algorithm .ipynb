# %%
import random
def buble_sort(l):
    for i in range(len(l)-1):
        for j in range(len(l)-i-1):
            if l[j]<l[j+1]:
                l[j],l[j+1]=l[j+1],l[j]
    return l
l=[]
for i in range(10):
    l.append(random.randint(100,999))
print(l)
buble_sort(l)
# Out:
# [280, 904, 725, 314, 833, 823, 427, 736, 135, 448]
# [904, 833, 823, 736, 725, 448, 427, 314, 280, 135]
