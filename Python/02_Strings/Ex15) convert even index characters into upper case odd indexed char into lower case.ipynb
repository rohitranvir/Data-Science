# %%
def fun(s):
    res=""
    for i in range(len(s)):
        if i%2==0:
            res+=s[i].upper()
        if i%2!=0:
            res+=s[i].lower()
    return res
s="rohitranvir"
fun(s)
# Out:
# 'RoHiTrAnViR'
