# %%
def fun(s):
    return len(s)

L = ["Ram", "Prabas", "Charan", "Tarak", "Arjun"]
print(L)
L.sort(key=fun)
print(L)
# Out:
# ['Ram', 'Prabas', 'Charan', 'Tarak', 'Arjun']
# ['Ram', 'Tarak', 'Arjun', 'Prabas', 'Charan']

# %%
def fun(s):
    return len(s)

L = ["Ram", "Prabas", "Charan", "Tarak", "Arjun"]
print(L)
L.sort(key=len)
print(L)
# Out:
# ['Ram', 'Prabas', 'Charan', 'Tarak', 'Arjun']
# ['Ram', 'Tarak', 'Arjun', 'Prabas', 'Charan']
