# %%
def fun(s):
    res=""
    for i in range(len(s)):
        res=res+(chr(ord(s[i])-32))
    return res
s="rohit"
fun(s)
# Out:
# 'ROHIT'

# %%
def fun(s):
    
    return s.upper()
s="rohit"
fun(s)
# Out:
# 'ROHIT'

# %%
# Out:
# 'tihor'
