# %%
import re
def fun(s):
    return len(re.findall("[ ]",s))
s="admin@pyt hon1234"
fun(s)
# Out:
# 1

# %%
import re
def fun(s):
    return len(re.findall(r"[\s]",s))
s="admin@pyt hon1234"
fun(s)
# Out:
# 1
