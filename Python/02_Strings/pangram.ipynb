# %%
def fun1(s):
    for i in range(97,123):
        if chr(i) not in s:
            return False
        # i+=1
    return True
        
print(fun1("the quick brown fox jumps over the lazy dog"))
print(fun1("the quick brown fox jumps over the lzy dog"))
# Out:
# True
# False
