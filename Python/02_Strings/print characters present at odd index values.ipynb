# %% [markdown]
# # print characters present at even index values

# %%
s=input("enter a value")
index=0
while index<(len(s)):
    if index%2!=0:
        print(s[index])
    index+=1
# Out:
# enter a value rohit
# o
# i
