# %% [markdown]
# # print characters present at even index values

# %%
    s=input("enter a string")
    index=0
    while index<(len(s)):
        if index%2==0:
            print(s[index],index)
        index+=1
# Out:
# enter a string rohit
# r 0
# h 2
# t 4
