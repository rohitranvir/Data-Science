# %%
import re
def fun(s):
    return "".join(re.findall("[a-zA-Z0-9]",s))
s="rohitranveer358@gmail.com%$"
fun(s)
# Out:
# 'rohitranveer358gmailcom'

# %%
import re
def fun(s):
    return "".join(re.sub("[^a-zA-Z0-9]","",s))
s="rohitranveer358@gmail.com%$"
fun(s)
# Out:
# 'rohitranveer358gmailcom'
