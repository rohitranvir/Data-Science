# %%
import re

def fun(s):
    return "".join(re.findall(r"[^aeioue]",s))
s="rohit"
fun(s)
# Out:
# 'rht'

# %%
import re

def fun(s):
    return "".join(re.sub(r"[aeioue]","",s))
s="rohit"
fun(s)
# Out:
# 'rht'
