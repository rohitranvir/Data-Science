# %%
def fun(s):
    low=0
    high=len(s)-1
    l1=""
    for i in s.split():
        if s[low]!=s[high]:
            return False
        low+=1
        high-=1
    return True
        
def fun1(s):
    l1=[]
    l=""
    for i in s.split():
        if fun(i):
            l1.append(i)
    # print(l1)
    l1.sort()
    for i in l1:
        if len(l)<len(i):
            l=i
    print(l)
    # print(s)
    # print(l1)
fun1("a ab abc aba madam sir malayalam liril prakash")
# Out:
# malayalam
