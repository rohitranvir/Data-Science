# %%
def fun(s):
    L = list(s)
    L.sort()
    return " ". join(L)
L=["rohit","amit","prabhakar","santosh","babasaheb"]
print (L)
fun(L)
# Out:
# ['rohit', 'amit', 'prabhakar', 'santosh', 'babasaheb']
# ['rohit', 'amit', 'prabhakar', 'santosh', 'babasaheb']
