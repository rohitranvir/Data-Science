# %%
def fun(s):
    s1=[]
    for i in s:
        s1.append(i)
    s1.sort()
    return " ".join(s1)
s="rohit" 
fun(s)
# Out:
# 'h i o r t'

# %%
def fun(s):
    l=list(s)
    l.sort()
    return " ".join(l)
s="rohit"
fun(s)
# Out:
# 'h i o r t'
