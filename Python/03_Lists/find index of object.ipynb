# %%
def fun(l,x):
    i=0
    for i in range(len(l)):
        if l[i]==x:
            return i
        else:
            return None
l=[1, 2, 3, 4, 5, 6]
x=3
print(fun(l,x))
# Out:
# None

# %%
def fun(l,x):
    return l.index(x)
l=[1,2,3,4,5,6,7]
x=4
fun(l,x)
# Out:
# 3

# %%
def fun(l):
    fmax=max(l)
    smax=None
    for i in l:
        if i!=fmax:
            if smax==None:
                smax=i
            else:
                smax=max(smax,i)
    return smax
    print(fmax)
l=[1,2,3,4,5,6,7]
fun(l)
# Out:
# 6

# %%
# Out:
# True
