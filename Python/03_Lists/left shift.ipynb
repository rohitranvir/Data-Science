# %%
l=[1,2,3,4,5]
l=l[1:]+l[0:1]
print(l)
# Out:
# [2, 3, 4, 5, 1]

# %%
l=[1,2,3,4,5]
l.append(l.pop(0))
print(l)
# Out:
# [2, 3, 4, 5, 1]

# %%
def fun(l):
    l1=[]
    for i in l[1:]:
        l1.append(i)
    l1.append(l[0])
    return l1
l=[1,2,3,4,5]
fun(l)
# Out:
# [2, 3, 4, 5, 1]

# %%
l=[1,2,3,4,5,6]
d=int(input("Enter a velue"))
for i in l[d:]:
    l.append(l.pop(0))
print(l)
# Out:
# Enter a velue 3
# [4, 5, 6, 1, 2, 3]

# %%
l=[1,2,3,4,5,6]
d=2
l1=[]
for i in l[d:]:
    l1.append(i)
l1.extend(l[0:d])

print(l1)
# Out:
# [3, 4, 5, 6, 1, 2]
