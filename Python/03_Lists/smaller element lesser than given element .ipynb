# %%
l=[9,11,15,12,3,7,14,10]
# s=sorted(l)
elem=10
lst=[]
for i in l:
    if i<elem:
        lst.append(i)
print(lst)
# Out:
# [9, 3, 7]

# %%
def fun1(l,x):
    return [i for i in l if i<x]
l=[9,11,15,12,3,7,14,10]
x=10
fun1(l,x)
# Out:
# [9, 3, 7]
