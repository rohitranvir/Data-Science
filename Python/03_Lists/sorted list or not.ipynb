# %%
def fun(l):
    
    for i in range(len(l)-1):
        if l[i]>l[i+1]:
            return False
    else:
        return True
l=[1,2,3,3,4]
fun(l)
# Out:
# True

# %%
def fun(l):
    i=1
    while i<len(l):
        if l[i]<l[i-1]:
            
            return False 
        i+=1
    return True
l=[1,2,3,4,5]
fun(l)
# Out:
# True

# %%
def fun(l):
    i=0
    while i<len(l)-1:
        if l[i]>l[i+1]:            
            return False 
        i+=1
    return True
l=[1,2,3,4,5]
fun(l)
# Out:
# True
