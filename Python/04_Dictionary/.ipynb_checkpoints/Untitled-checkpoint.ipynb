# %%
names=["Rohit","Santosh","ranvir","Pratham"]
l2=[20,30,40,50]
l3={i:j for i,j in zip(names,l2)}
print(l3)
# Out:
# {'Rohit': 20, 'Santosh': 30, 'ranvir': 40, 'Pratham': 50}

# %%
l={'Rohit': 20, 'Santosh': 30, 'ranvir': 40, 'Pratham': 50}
l["Pratham"]=500
print(l)
# Out:
# {'Rohit': 20, 'Santosh': 30, 'ranvir': 40, 'Pratham': 500}

# %%
d1={"Ramesh":20}
d2={"Suresh":30}
print(d1.update(d2))
# Out:
# None

# %% [raw]
# 'clear',     =>>Dictionary clear
#  'copy',     ==>Copy
#  'fromkeys', ==>
#  'get',      ==>Get some value
#  'items',    ==>kays and values pair come
#  'keys',     ==> only keys
#  'pop',      ==> delete
#  'popitem',  ==> delete
#  'setdefault',=>
#  'update',   ==>extend
#  'values'   ==>only values

# %%
l1={'Rohit': 20, 'Santosh': 30, 'ranvir': 40, 'Pratham': 500}
print(l1.pop("Rohit"))
print(l1)
# Out:
# 20
# {'Santosh': 30, 'ranvir': 40, 'Pratham': 500}

# %%
l={'Rohit': 20, 'Santosh': 30, 'ranvir': 40, 'Pratham': 50}
print(l.clear())
# Out:
# None

# %%
l={'Rohit': 20, 'Santosh': 30, 'ranvir': 40, 'Pratham': 50}
l1=l.copy()
print(l1)
# Out:
# {'Rohit': 20, 'Santosh': 30, 'ranvir': 40, 'Pratham': 50}

# %%
l={'Rohit': 20, 'Santosh': 30, 'ranvir': 40, 'Pratham': 50}
d2={"Suresh":30}
l1=l.update(d2)
print(l)
# Out:
# {'Rohit': 20, 'Santosh': 30, 'ranvir': 40, 'Pratham': 50, 'Suresh': 30}

# %%
l={'Rohit': 20, 'Santosh': 30, 'ranvir': 40, 'Pratham': 50}
l2=l.pop("")
print(l2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[51], line 2
#       1 l={'Rohit': 20, 'Santosh': 30, 'ranvir': 40, 'Pratham': 50}
# ----> 2 l2=l.pop()
#       3 print(l2)
#
# TypeError: pop expected at least 1 argument, got 0

# %%
l={'Rohit': 20, 'Santosh': 30, 'ranvir': 40, 'Pratham': 50}
l1=list(l.items())
print(l1)
# Out:
# [('Rohit', 20), ('Santosh', 30), ('ranvir', 40), ('Pratham', 50)]

# %%
l={'Rohit': 20, 'Santosh': 30, 'ranvir': 40, 'Pratham': 50}
l.keys()
# Out:
# dict_keys(['Rohit', 'Santosh', 'ranvir', 'Pratham'])

# %%
l={'Rohit': 20, 'Santosh': 30, 'ranvir': 40, 'Pratham': 50}
l1=l.get(1)
print(l.getet(0))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[29], line 3
#       1 l={'Rohit': 20, 'Santosh': 30, 'ranvir': 40, 'Pratham': 50}
#       2 l1=l.get(1)
# ----> 3 print(l.getet(0))
#
# AttributeError: 'dict' object has no attribute 'getet'

# %%
l={'Rohit': 20, 'Santosh': 30, 'ranvir': 40, 'Pratham': 50}
l.popitem()
# Out:
# ('Pratham', 50)

# %% [markdown]
# # Remove
#  ======> pop
#
#  ======> pop item
#
#  ======> del

# %%
l={'Rohit': 20, 'Santosh': 30, 'ranvir': 40, 'Pratham': 50}
del(l["ranvir"])
print(l)
# Out:
# {'Rohit': 20, 'Santosh': 30, 'Pratham': 50}

# %%
d1={'apple':20,'Banana':30}
d2={'Chery':40}
d1.update(d2)
print(d1)
# Out:
# {'apple': 20, 'Banana': 30, 'Chery': 40}

# %%
d1={'Rohit': 20, 'Santosh': 30, 'ranvir': 40, 'Pratham': 50}
#d1['hii']     # Error
d1.setdefault('Grade') # Insertion happned with None as key
print(d1)
# Out:
# {'Rohit': 20, 'Santosh': 30, 'ranvir': 40, 'Pratham': 50, 'Grade': None}

# %%
d1={'Rohit': 20, 'Santosh': 30, 'ranvir': 40, 'Pratham': 50}
d1['Grade']='A'
print(d1)
# Out:
# {'Rohit': 20, 'Santosh': 30, 'ranvir': 40, 'Pratham': 50, 'Grade': 'A'}

# %% [markdown]
# Set defalut is only for None and new value
# And it will not change already existed value
