# %% [markdown]
# # Class Attribute

# %%
class Student:
    collage="Babasaheb naik"
    
print(s1.collage)
# Out:
# Babasaheb naik

# %%
class Student:
    def __init__(self,name):
        self.name=name
s1=Student('rohit')
print(s1.name)
# Out:
# rohit
