# %%
class Account:
    def __init__(self,bal,accno):
        self.bal=bal
        self.accno=accno
    def trans(self):
        print(f"Your ac balance is {self.bal}")
        de=input("Enter a option for transaction ")
        if de=="debit":
            debit=int(input("Enter a number of amount that you want to withdrawal"))
            balance=self.bal-debit
            print(f"Your ac balance is {balance}")
        elif de=="credit":
            credit=int(input("Enter a number of amount that you want to withdrawal"))
            balance=self.bal+credit
            print(f"Your ac balance is {balance}")
s=Account(100,1)
s.trans()
# Out:
# Your ac balance is 100
# Enter a option for transaction  credit
# Enter a number of amount that you want to withdrawal 100
# Your ac balance is 200

# %%
class Account:
    def __init__(self,balance,acc):
        self.balance=balance
        self.acc=acc
    def debit(self,amount):
        self.amount=amount
        self.balance-=self.amount
        print(f"debited amount {self.amount} and account balance {self.balance}")
    def credit(self,amount):
        self.amount=amount
        self.balance+=self.amount
        print(f"Credited amount {self.amount} and account balance {self.balance}")
s=Account(100,1)
s.debit(20)
s.credit(5)
# Out:
# debited amount 20 and account balance 80
# Credited amount 5 and account balance 85
