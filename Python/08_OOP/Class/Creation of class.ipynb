# %%
class Student:
    def __init__(a):
        a.name='Rohit'
        a.Rollno=101
        a.marks=95
    def talk(self):
        print(self.name)
s=Student()
s.name
# Out:
# 'Rohit'

# %%
class Student:
    def __init__(self,name,surname):
        self.name=name
        self.surname=surname
    def display(self,):
        print(self.name)
s=Student('Rohit','Ranvir')
s.display()
# Out:
# Rohit
