# %%
class Student:
    def paren(self):
        self.name="This is parent "
        print(self.name)
class child(Student):
    def __init__(self):
        self.name="This is child"
s=child()
s.paren()
# Out:
# This is parent
