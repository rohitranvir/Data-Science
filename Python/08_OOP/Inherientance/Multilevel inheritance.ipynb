# %%
class parent:
    def car(self):
        self.comp="Mercedies"
        print(self.comp)
        s
class child(parent):
    def model(self):
        self.model="GLS-650"
        print(self.model)
        self.car()
        
class grandp(child):
    def establi(self):
        self.year=1990
        print(self.year)   
        self.model()
s=grandp()
s.establi()
# s.model()
# s.car()
# Out:
# 1990
# GLS-650
# Mercedies
