# %% [markdown]
# # inheritance is a mechanism which is used to acquire a properties of parent class
# # Type of Inheritance
# 1. single inheritance ==>>>>>>>  (One parent => one child )
# 2. multilevel Inheritance =>>>>> (Grandparent => parent => child)
# 3. multiple inheritance =>>>()
