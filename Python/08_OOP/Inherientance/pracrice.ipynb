# %%
class ClassA:
    def company(self):
        self.name="mercedies"
        print(self.name)
class ClassB:
    def pcomp(self):
        self.year=1990
        print(self.year)
        self1.company()
class ClassC(ClassA,ClassB):
    def model(self1):
        self1.model="Benz"
        self1.pcomp()
s=ClassC()
print(s.model())
# Out:
# 1990
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 15
#      13         self1.pcomp()
#      14 s=ClassC()
# ---> 15 print(s.model())
#
# Cell In[16], line 13, in ClassC.model(self1)
#      11 def model(self1):
#      12     self1.model="Benz"
# ---> 13     self1.pcomp()
#
# Cell In[16], line 9, in ClassB.pcomp(self)
#       7 self.year=1990
#       8 print(self.year)
# ----> 9 self1.company()
#
# NameError: name 'self1' is not defined
