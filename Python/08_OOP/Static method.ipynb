# %% [markdown]
# # Static Methods
# Methods that don't use the self parameter (work at class level)
#
# class Student:
# @staticmethod
# def college( ):
# print( "ABC College" )
#
# #decorator
#
# *Decorators allow us to wrap another function in order to
# extend the behaviour of the wrapped function, without
# permanently modifying it

# %%
class Student:
    @staticmethod
    def hello():
        print("hellow rohit")
s=Student()
s.hello()
# Out:
# hellow rohit

# %% [markdown]
# # we must have to follow this syntax or we must have to use =>>> @staticmethod (Decoder) other wise we will get error because in class we must have to use self inside methods inside class

# %%
class Student:
    def hello():
        print("hello")
s=Student()
s.hello()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 5
#       3         print("hello")
#       4 s=Student()
# ----> 5 s.hello()
#
# TypeError: Student.hello() takes 0 positional arguments but 1 was given
