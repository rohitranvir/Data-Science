# %%
class Student:
    college="babasabeb naik"
    def __init__(self,name,surname,marks,ranks):
        self.name=name
        self.surname=surname
        self.marks=marks
        self.ranks=ranks
    def information(self):
        print(self.college)
        print(self.surname)
s=Student("Rohit","Ranvir",95,1)
s.information()
# Out:
# babasabeb naik
# Ranvir

# %%
class Student:
    college="babasabeb naik"
    def __init__(self,name,surname,marks,ranks):
        self.name=name
        self.surname=surname
        self.marks=marks
        self.ranks=ranks
    def information(self):
        print(self.college)
        print(self.surname)
s=Student("Rohit","Ranvir",95,1)
s.information()
# Out:
# babasabeb naik
# Ranvir
