# %%
def binaryse(l,key):
    low=0
    high=len(l)-1
    while low<=high:
        mid=(low+high)//2
        if key==l[mid]:
            return mid
        elif key<l[mid]:
            high =mid-1
        else:
            low=mid+1
    return -1
l=[10,20,5,0,80,95,68,10,20,10]
l.sort()
binaryse(l,20)
# Out:
# 5

# %%
def binaryse(l,key,low,high):
    if low>high:
        return -1
    mid=(low+high)//2
    if key==l[mid]:
        return mid
    elif key<l[mid]:
        return binaryse(l,key,low,mid-1)
    else:
        return binaryse(l,key,mid+1,high)
    
l=[10,20,5,0,80,95,68,10,20,10]

l.sort()
print(l)
binaryse(l,20,0,len(l)-1)
# Out:
# [0, 5, 10, 10, 10, 20, 20, 68, 80, 95]
# 5
