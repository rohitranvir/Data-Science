# %%
try:
    a=[10,20,30,40,50,60]
    b=[]
    for i in range(len(a)+1):
        b.append(a[i])

except IndexError:
    print("This index is wrong Because this is going out out list")
else:
    print(b,"This is list")
finally:
    print("Exectution successful")
# Out:
# This index is wrong Because this is going out out list
# Exectution successful
