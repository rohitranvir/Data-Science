# %% [markdown]
# ## Exception handaling is a error control mechanism whitch is used to deals with Handaling error that occure after program run its purpose is not to hide error but shows the error and prevent program from crashing
#
# #  Why exce ption exit
# 1. invalid user input
# 2. missing files
# 3. division by zero
# 4. Null access
#
# # Without Exception handaling
# 1. The program may crush
#
# # Exception Handaling is help program to fail safely for silently

# %%
try:
    x= int(input("Enter a number"))
    y = 10
    Z=y/x
    print(Z)
except ZeroDivisionError:
    print("Division by zero is not allowed")
except ValueError:
    print("Invalid input Integer Required")
else:
    print("Exceusion Successfull")
finally:
    print('Cleanup successfull')
# Out:
# Enter a number str
# Invalid input Integer Required
# Cleanup successfull

# %% [markdown]
# # try :
#   1. his block contain code that may fail
#   2. If exception occure regular flow may stop
# # except :
#   1. Handle Specific Failure type
# # else:
#    1. Run only if no exception occure
# # finally:
#   1. Always run successfull or fail

# %% [markdown]
# # Built-in exceptions (common and important)
# | Exception           | When it occurs                  |
# | ------------------- | ------------------------------- |
# | `ZeroDivisionError` | Divide by zero                  |
# | `ValueError`        | Wrong data type/value           |
# | `TypeError`         | Invalid operation between types |
# | `IndexError`        | Index out of range              |
# | `KeyError`          | Missing dictionary key          |
# | `FileNotFoundError` | File doesn’t exist              |

# %% [markdown]
# # raise:
#    raise Exception("Error Message")
# # Why raise exists=>
# Not all error is techinical some error are logical or business rule violation
#
# ex=>
#
# 1. Age must be>=18
# 2. Balance Connot be negative
# 3. File format must be csv
#
# # ex=>

# %%
age=int(input("Enter a age"))
if age<18:
    raise ValueError ("Age must be greater that 18")
print("Access Grant")
# Out:
# Enter a age 17
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 3
#       1 age=int(input("Enter a age"))
#       2 if age<18:
# ----> 3     raise ValueError ("Age must be greater that 18")
#       4 print("Access Grant")
#
# ValueError: Age must be greater that 18
