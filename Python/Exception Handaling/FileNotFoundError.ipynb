# %%
try:
    file = open("data.txt", "r")
    print(file.read())

except FileNotFoundError:
    print("Error: File not found")

finally:
    print("File access attempt completed")
# Out:
# Error: File not found
# File access attempt completed
