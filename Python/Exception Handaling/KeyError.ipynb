# %%
try:
    d={"Rohit":1,"santosh":2,"ranvir":3}
    print(d["Rohit"])
except KeyError:
    print("This key is not available")
else:
    print("Key found")
finally:
    print("Code executed")
# Out:
# 1
# Key found
# Code executed
