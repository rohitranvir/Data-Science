# %%
try:
    x= int(input("ENter a value"))
    y= 10/x
    print(y)
except ZeroDivisionError:
    print("VAlue Must be grether than Zero")
except ValueError:
    print("Value Must be integer")
else:
    print("Execution complated ")
finally:
    print("Code executed")
# Out:
# ENter a value 0
# VAlue Must be grether than Zero
# Code executed
