# %%
with open(r"D:\Data-Science\Python\File Handaling\data1.txt","r") as f:
    print(f.read())
# Out:
# Hiiiiiii ia m rohit

# %% [markdown]
# 1. Reads entire file
#
# 2. Used for small text files or binary loading
#
# 3. Do NOT use for large files
