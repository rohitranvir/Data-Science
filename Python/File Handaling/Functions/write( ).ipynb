# %%
with open(r"D:\Data-Science\Python\File Handaling\data1.txt","w") as f:
    f.write("welcome to hydrabad")
with open(r"D:\Data-Science\Python\File Handaling\data1.txt","r") as f1:
    print(f1.read())
# Out:
# welcome to hydrabad

# %% [markdown]
# 1. Writes data to file
# 2. Accepts only one argument
# 3. Does NOT add newline automatically
