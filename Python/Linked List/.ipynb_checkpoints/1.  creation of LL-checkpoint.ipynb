# %%
class node:
    def __init__(self,data):
        self.data=data
        self.next=None
head=node(10)
print(head.data)
print(head.next)
# Out:
# 10
# None

# %%
head.next=node(20)
print(head.next.data)
# Out:
# 20

# %%
head.next.next=30
porint(head.next.data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 head.next.next=30
#       2 porint(head.next.data)
#
# AttributeError: 'int' object has no attribute 'next' and no __dict__ for setting new attributes
