# %%
class Node:
    def middleNode(self,data):
        self.data=data
        self.next=None
s=Node()
s.middleNode(1)
head.next=Node(2)
head.next.next=Node(3)
head.next.next.next=Node(4)
head.next.next.next.next=Node(5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 7
#       5 s=Node()
#       6 s.middleNode(1)
# ----> 7 head.next=Node(2)
#       8 head.next.next=Node(3)
#       9 head.next.next.next=Node(4)
#
# TypeError: Node() takes no arguments
