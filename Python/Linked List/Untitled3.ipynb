# %%
class node:
    def __init__(self,data):
        self.data=data
        self.next=None
    
l=[1,2,3,3,4,4,5]
head=node(l[0])
curr=head
for i in l[1:]:
    curr.next=node(i)
    curr=curr.next

# %%
def delet(head):
    dummy = node(0)
    head=dummy.next
    prev=dummy
    curr=head
    if curr.data==curr.next.data:
        while curr.next.data==curr.data:
            prev=curr.next
    else:
        
    
delet(head)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[74], line 17
#      13         curr=curr.next
#      15     return dummy.next
# ---> 17 delet(head)
#
# Cell In[74], line 6, in delet(head)
#       4 prev=dummy
#       5 curr=head
# ----> 6 if curr.data==prev.next.data:
#       7     val=curr.data
#       8     while curr and curr.data==val:
#
# AttributeError: 'NoneType' object has no attribute 'data'

# %%
# Out:
# 1 2 3 4 5

# %%
def trav(head):
    curr=delet(head)
    while curr!=None:
        print(curr.data)
        curr=curr.next
trav(head)
# Out:
# 1
# 2
# 3
# 4
# 5
