# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.next=None
    
l=[2,1,3,5,6,4,7]
head=Node(l[0])
temp=head
# head.next=Node(l[1])
for i in l[1:]:
    temp.next=Node(i)
    temp=temp.next
    

head.next.next.data
# Out:
# 3

# %%
temp=head
lst=[]
while temp:
    lst.append(temp.data)
    if temp.next:
        temp=temp.next.next
    else:
        break
temp=head.next
while temp:
    lst.append(temp.data)
    if temp.next:
        temp=temp.next.next
    else:
        break
    
print(lst)
head=Node(lst[0])
temp=head
# head.next=Node(l[1])
for i in lst[1:]:
    temp.next=Node(i)
    temp=temp.next
    

head.next.next.data
# Out:
# [2, 3, 6, 7, 1, 5, 4]
# 6
