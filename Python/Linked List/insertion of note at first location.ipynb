# %%
class node:
    def __init__(self,data):
        self.data=data
        self.next=None
head=node(10)
head.next=node(20)
head.next.next=node(30)
print(head.data)
print(head.next.data)
print(head.next.next.data)
# Out:
# 10
# 20
# 30

# %%
def printlist(head):
    temp=head
    if temp==None:
        print("None")
        return 
    while temp!=None:
        print(temp.data,end="=>")
        temp=temp.next
    print(None)    
printlist(head)
# Out:
# 10=>20=>30=>None

# %%
def insertatfirst(head,data):
    temp=node(data)
    temp.next=head
    return temp
head1=None
head1=insertatfirst(head1,444)
printlist(head1)
# Out:
# 444=>None
