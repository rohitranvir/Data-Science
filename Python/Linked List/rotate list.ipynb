# %%
class node:
    def __init__(self,data):
        self.data=data
        self.next=None
    
l=[1,2,3,4,5]
# k=2
head=node(l[0])
curr=head
for i in l[1:]:
    curr.next=node(i)
    curr=curr.next

# %%
def tranverse(head):
    curr=head
    while curr!=None:
        print(curr.data)
        curr=curr.next
tranverse(head)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
def rot(head):
    k=2
    k=k%2
    if k==0:
        return head
    while
