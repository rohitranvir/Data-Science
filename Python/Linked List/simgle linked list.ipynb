# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.next=None
head=Node(10)
head.next=Node(20)
head.next.next=Node(30)
print(head.next.next.data)
# Out:
# 30

# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.next=None
class singlelinked:
    def __init__(self):
        self.head=None
    def append(self,data):
        new_node=Node(data)
        if self.head is None:
            self.head=new_node   
        else:
            curr=self.head
            while self.curr is not None:
                curr=curr.next
            curr.next=new_node
    def traverse(self):
        if not self.head:
            print("Sil is emplty")
        else:
            curr=self.head
            while curr is not None:
                print(curr.data,end=" ")
                curr=curr.next
            print()

s=singlelinked()
s.append(50)
s.append(60)
s.traverse()
# print(head.next.next.data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[26], line 29
#      27 s=singlelinked()
#      28 s.append(50)
# ---> 29 s.append(60)
#      30 s.traverse()
#      31 # print(head.next.next.data)
#
# Cell In[26], line 14, in singlelinked.append(self, data)
#      12 else:
#      13     curr=self.head
# ---> 14     while self.curr is not None:
#      15         curr=curr.next
#      16     curr.next=new_node
#
# AttributeError: 'singlelinked' object has no attribute 'curr'
