# %% [markdown]
# ## palindrome string

# %%
def pali(s,start,end):
    if start>=end:
        return True
    return s[start]==s[end] and pali(s,start+1,end-1)
s="madam"
# s="sir"
pali(s,0,len(s)-1)
# Out:
# True
