# %%
def fala(arr,target):
    first=-1
    last=-1
    for i in range(len(nums)):
        if arr[i]==target:
            if first==-1:
                first=i
            last=i
    return [first,last]

target=3
nums = [1, 2, 3, 3, 3, 3, 5, 6, 8, 9, 9, 10]
fala(nums,target)
# Out:
# [2, 5]

# %%
def fala(arr,target):
    first=-1
    =-1
    for i in range(len(nums)):
        if arr[i]==target:
            if first==-1:
                first=i
            last=i
    return [first,last]

target=3
nums = [1, 2, 3, 3, 3, 3, 5, 6, 8, 9, 9, 10]
fala(nums,target)

# %%
def find(ar,t):
    low=0
    high=len(ar)-1
    while low<=high:
        mid=(low+high)//2
        
        if ar[mid]==t:
            return True
        elif ar[low]==ar[mid]==ar[high]:
            low+=1
            high-=1
            continue
        elif ar[mid]>=ar[low]:            
            if ar[mid]<=t<=ar[high]:
                low+=1
            else:
                high=mid-1
        else:
            if ar[low]<=t<=ar[mid]:
                high=mid-1
            else:
                low=mid+1
        # elif ar[mid]!=ar[high]:
        #     if ar[low]<=t<=ar[mid]:
        #         high=mid-1
        #     else:
        #         low+=1
    return False 
l=[13,1,1,1]
find(l,13)
# Out:
# False

# %%
def findmin(l):
    m=l[0]
    low =0
    high=len(l)-1
    while low<=high:
        mid=(low+high)//2
        # print(l[mid])
        if l[mid]<=m:
            m=l[mid]
        if l[mid]>m:
            low=mid+1
            
        else:
            high=mid-1
    return m
l=[4,5,6,7,0,1,2]
findmin(l)
# Out:
# 0

# %%
def findmin(l):
    m=l[0]
    low =0
    high=len(l)-1
    while low < high:
        mid = (low + high) // 2
    
        if l[mid] > l[high]:
            low = mid + 1
        else:
            high = mid

    return l[low]
l=[1, 2, 3, 3, 3, 3, 5, 6, 8, 9, 9, 10]
findmin(l)
# Out:
# 1
