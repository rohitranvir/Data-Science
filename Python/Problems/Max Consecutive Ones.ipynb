# %%
l=[1,1,0,1,1,1]
count=0
max_c=0
for i in range(len(l)):
    if l[i]==1:
        count+=1
    else:
        max_c=max(max_c,count)
        count=0 
print(max(max_c,count))
print(max_c)
# Out:
# 3
# 2
