# %%
def rem(num):
    pos =2
    for i in range(2,len(num)):
        if num[i]!=num[i-2]:
            num[pos]=num[i]
            pos+=1
    return num
nums = [1,1,1,2,2,3]
rem(nums)
# Out:
# [1, 1, 2, 3, 2, 3]

# %%
def maj(num):
    dic={}
    for i in num:
        if i not in dic:
            dic[i]=1
        else:
            dic[i]+=1
    res=max(dic,key=dic.get)
    return res
    #     # for j in range(len(num)):
    #     #     if v in num:
    #     #         count+=1        
    #     # if count>c:
    #     #     val=v
    #     #     c=count
    # return val
num = [2,2,1,1,1,2,2,1,1]
maj(num)
# Out:
# 1

# %%
def rot(num,k):
    c=0
    num.reverse()
    num[:k]=reversed(num[:k])
    num[k:]=reversed(num[k:])
    return num
    # if k==len(num):
    #     return num
    # return num[len(num)-k:]+num[:len(num)-k]
    # return 
nums = [1,2,3,4,5,6,7]
k = 3
rot(nums,k)
# Out:
# [5, 6, 7, 1, 2, 3, 4]

# %%
def rem(num,val):
    c=0
    for i in range(len(num)-1):
        if num[i]!=val:
            # num.pop(num[i])
            num[c]=num[i]
            c+=1
    return num[:c]
nums = [3,2,2,3]
val = 3
rem(nums,val)
# Out:
# [2, 2]
