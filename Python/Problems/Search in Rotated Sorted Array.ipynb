# %%
def find(l,t):
    low=0
    high=len(l)-1
    while low<=high:
        mid=(low+high)//2
        print(mid)
        if l[mid]==t:
            return mid            
        elif l[mid]>t:
            high=mid-1            
        else:
            low=mid+1
    return -1
l=[0,1,2,3,4,5,6,7]
t = 2
find(l,t)
# Out:
# 3
# 1
# 2
# 2

# %%
def find(l,t):
    low=0
    high=len(l)-1
    while low<=high:
        mid=(low+high)//2
        if l[mid]==t:
            return mid            
        if l[mid]<=l[high]:
            if l[mid]<=t<=l[high]:
                low=mid+1
            else:
                high=mid-1
        else:
            if l[low]<=t<=l[mid]:
                high=mid-1
            else:
                low=mid+1    
    return -1
l=[17,18,20,1,3,4,5,7,8,10,11,13,14,16]
t = 3
find(l,t)
# Out:
# 6
# 2
# 4
# 4
