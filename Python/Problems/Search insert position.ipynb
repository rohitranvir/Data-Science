# %%
def searchInsert(nums, target):
    for i in range(len(nums)):
        if nums[i] >= target:
            return i
    return len(nums)

nums = [1,3,5,6] 
target = 2
searchInsert(nums, target)
# Out:
# 1

# %%
def searchInsert(nums, target):
    low=0
    res=len(nums)    
    high=len(nums)-1
    while low<high:
        mid=(low+high)//2
        if nums[mid]>=target:
            res=mid 
            high=mid-1
        else:
            low=mid+1
    return res
        # if 
nums = [1,3,5,6] 
target = 3
searchInsert(nums, target)
# Out:
# 1
