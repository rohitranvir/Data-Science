# %%
def thrsum(num):
    # start=0
    res=[]
    # while start< len(num)-3:
    #     for i in range(1,len(num)-2):
    #         for j in range(2,len(num)-1):
    #             if num[start]+num[i]+num[j]==0:
    #                 res.append([num[start],num[i],num[j]])
    #     start+=1
    # i=0
    # start=1

    # num.sort()
    # while start<left:
    #     total=num[i]+num[start]+num[left]
    #     if total==0:
    #         res.append([num[i],num[start],num[left]])
    #     start+=1
    num.sort()
    for i in range(len(num)-2):
        if i>0 and num[i]!=num[i+1]:
            continue
        start=i+1
        left=len(num)-1
        while start<left:
            total=num[i]+num[start]+num[left]
            if total==0:
                res.append([num[i],num[start],num[left]])
                start+=1
                left-=1
            elif total<0:
                start+=1
            else:
                left-=1
            
        # i+=1
        
    return res
    
                        
                    

nums = [-1,0,1,2,-1,-4]
thrsum(nums)
# Out:
# [[-1, -1, 2], [-1, 0, 1]]
