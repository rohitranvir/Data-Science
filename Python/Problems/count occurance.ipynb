# %% [markdown]
# # Brute Force
# ## TC=O(N)
# ## SC=O(1)

# %%
l=[8, 9, 10, 12, 12, 12]
target = 12
res=0
for i in range(len(l)):
    if l[i]==target:
        res+=1
print(res)
# Out:
# 3

# %% [markdown]
# # Optimal Solution

# %%
def lowerbound(l,t):
    low=0
    high=len(l)-1
    lb=0
    while low<=high:
        mid=(low+high)//2
        if l[mid]>=t:
            high=mid-1
            lb=mid
        else:
            low=mid+1
    if lb==-1:
        return 0
    return upperbound(l,t)-lb
    
def upperbound(l,t):
    low=0
    high=len(l)-1
    ub=len(l)
    while low<=high:
        mid=(low+high)//2
        if l[mid]>t:
            ub=mid
            high=mid-1
        else:
            low=mid+1
    return ub
        
l=[8, 9, 10, 12, 12, 12]
target = 
lowerbound(l,target)
# Out:
# 6

# %%
if l[mid] >= t:
    lb = mid
    high = mid - 1
else:
    low = mid + 1
