# %%
nums=[1,1,1,2,3,12,3,1,2,1,23,5,5,5,5,31,3,1,1,1,1,15]
dic={}
for i in nums:
    if i not in dic:
        dic[i]=1
    else:
        dic[i]+=1
print(len(dic))
# Out:
# 8

# %%
nums=[1,1,1,2,3,12,3,1,2,1,23,5,5,5,5,31,3,1,1,1,1,15]
for i in range(0,len(nums)-1):
    for j in range(1,len(nums)-1):
        if nums[i]!=nums[j]:
            nums[i]=nums[j]
            i+=1
    print(i)
    break
# Out:
# 17

# %%
nums=[1,1,1,2,3,12,3,1,2,1,23,5,5,5,5,31,3,1,1,1,1,15]
nums.sort()
k=1
for i in range(1,len(nums)):
    if nums[i]!=nums[i-1]:
        nums[k]=nums[i]
        k+=1
print(nums[:k])
# Out:
# [1, 2, 3, 5, 12, 15, 23, 31]
