# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.next=None
l=[1,2,3,4,5]
head=Node(l[0])
curr=head
for i in l[1:]:
    curr.next=Node(i)
    curr=curr.next

# %%
def trav(head):
    while head != None:
        print(head.data)
        head=head.next
trav(head)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
def rem(head,n=2):
    length=0
    curr=head
    while curr != None:
        curr=curr .next
        length+=1
    pos_to_stop=length-n
    
rem(head)
# Out:
# 5

# %%
def mergeAlternately(w1,w2):
        s=""
        # leng=len(max(w2,w2))
        count=0
        len1=len(w1)
        len2=len(w2)
        leng=min(len1,len2)
        for i in range(leng):
            s+=w1[i]
            s+=w2[i]            
        if len1<len2:
            s+=w2[leng:]
        else:
            s+=w1[leng:]
        return s
word1="abc"
word2="pqrdf"
mergeAlternately(word1,word2)
# Out:
# 'apbqcrdf'

# %%
s="roh"
s1="rohitranvir"
if s in s1:
    print("yes")
# Out:
# yes
