# %%
def sale(ar):
    c=0
    res={}
    for i in range(len(ar)):
        if ar[i] not in res:
            res[ar[i]]=1
        else:
            res[ar[i]]+=1
    # for i in range(len(ar)):
    #     count=0
    #     for j in range(i,len(ar)):
    #         if ar[i]==ar[j]:
    #             count+=1
    #         if count==2:
    #             count=0
    #             c+=1  
    for i in res:
        c+=res[i]//2
    return c
            
ar = [1, 1, 3, 1, 2, 1, 3, 3, 3, 3]
sale(ar)
# Out:
# 4

# %%
def sale(ar):
    min_s=0
    max_s=0
    c=ar[0]
    for i in range(len(ar)):
        if ar[i]>c:
            c=ar[i]
            max_s+=1
    c=ar[0]
    for i in range(len(ar)):
        if ar[i]<c:
            c=ar[i]
            min_s+=1   
        
    return max_s,min_s
ar=[3, 4, 21, 36, 10, 28, 35, 5, 24, 42]
sale(ar)
# Out:
# (4, 0)
