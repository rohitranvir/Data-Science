# %%
1️⃣ Check if an array is sorted

Problem
Given an array of integers, check recursively whether it is sorted in non-decreasing order.

Input

arr = [1, 2, 4, 7, 9]


Output

True


Edge cases

Empty array → True

Single element → True

Duplicate elements allowed

Hint

Compare arr[i] and arr[i+1]

Reduce the problem size by moving index forward

2️⃣ Find first occurrence of an element

Problem
Find the first index of a given element x in an array using recursion.

Input

arr = [3, 5, 2, 5, 8, 5]
x = 5


Output

1


If not found

-1


Hint

Start from index 0

Stop recursion once found

3️⃣ Find last occurrence of an element

Problem
Find the last index of element x using recursion.

Input

arr = [3, 5, 2, 5, 8, 5]
x = 5


Output

5


Hint

Go to the end first

Decide during the return phase

4️⃣ Reverse a string

Problem
Reverse a string using recursion.

Input

s = "recursion"


Output

"noisrucer"


Restrictions

Do NOT use slicing

Do NOT use loops

Hint

First character + recursive call on rest

5️⃣ Remove duplicate characters

Problem
Remove duplicate characters from a string while preserving order.

Input

s = "programming"


Output

"progamin"


Hint

Use a helper structure (set or boolean array)

Pass it through recursive calls

6️⃣ Check if a string is a palindrome

Problem
Check if a string reads the same forward and backward.

Input

s = "madam"


Output

True


Input

s = "hello"


Output

False


Hint

Compare first and last characters

Shrink the string from both ends
