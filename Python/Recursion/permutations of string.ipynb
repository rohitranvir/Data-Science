# %%
def per(s,ans):
    if s=="":
        global c
        c=c+1
        print(ans)
        return
    for i in range(0,len(s)):
        per(s[:i]+s[i+1:],ans+s[i])
c=0
per("abd",'')
print(c)
# Out:
# abd
# adb
# bad
# bda
# dab
# dba
# 6
