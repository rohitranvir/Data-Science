# %%
import re
s="(123)+456##"
pt=r"^\(\d{3}\)\+\d{3}#{2}$"
print(re.findall(pt,s))
# Out:
# ['(123)+456##']

# %%
import re
string="<HTML><HEAD<TITLE>this is html page</TITLE></HEAD></HTML>"
pt=r">([^<]+)"
print(re.findall(pt,string))
# Out:
# ['this is html page']

# %%
string="this is python class"
pt="[aeiouAEIOU]"
print(re.findall(pt,string))
# Out:
# ['i', 'i', 'o', 'a']

# %%
string="this is python class"
pt="[^aeiouAEIOU]"
print(re.findall(pt,string))
# Out:
# ['t', 'h', 's', ' ', 's', ' ', 'p', 'y', 't', 'h', 'n', ' ', 'c', 'l', 's', 's']

# %%
string="198.168.233.150"
pt="[0-9.]+"
print(re.findall(pt,string))
# Out:
# ['198.168.233.150']

# %%
string="198.168.233.150"
pt=r"[\d.]+"
print(re.findall(pt,string))
# Out:
# ['198.168.233.150']

# %%
string="Rohit@358"
pt=r"[\w\W]{8,}"
print(re.findall(pt,string))
# Out:
# ['Rohit@358']

# %%
password="Rohit@358"
pt=r"^(?=.*[A-Z])(?=.*[a-z])(?=.*\d)(?=.*[@$!%*?&]).+$"
print(re.findall(pt,string))
# Out:
# ['Rhit@358']

# %%
s="abojjksdjfbb"
pt="^ab.*bb$"
print(re.findall(pt,s))
# Out:
# ['abojjksdjfbb']

# %%
s="\C:text2\text1\abx.txt"
pt=r"[a-z]+"
print(re.findall(pt,s))
# Out:
# ['text', 'ext', 'bx', 'txt']
# <>:1: SyntaxWarning: invalid escape sequence '\C'
# <>:1: SyntaxWarning: invalid escape sequence '\C'
# C:\Users\rohit\AppData\Local\Temp\ipykernel_19184\4108299989.py:1: SyntaxWarning: invalid escape sequence '\C'
#   s="\C:text2\text1\abx.txt"

# %%
s="abcdfdoopfdsjjfkjdsfppkl"
pt=r"((.)\2)"
print(re.findall(pt,s))
# Out:
# [('oo', 'o'), ('jj', 'j'), ('pp', 'p')]
