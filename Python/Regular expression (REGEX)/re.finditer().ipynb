# %%
import re

text = "Python is powerful. Python is easy."

result = re.finditer("Python", text)

for match in result:
    print(match.group(), "found at position", match.start())
# Out:
# Python found at position 0
# Python found at position 20
