# %%
import random
def selection_sort(l):
    c=0
    for i in range(len(l)-1):
        min_i=i
        for j in range(i+1,len(l)):
            if l[j]<l[min_i]:
                
                min_i=j
        l[i],l[min_i]=l[min_i],l[i]
    return l
l=[]
for i in range(10):
    l.append(random.randint(100,999))
print(l)
selection_sort(l)
# Out:
# [846, 137, 457, 421, 965, 949, 613, 395, 798, 101]
# [101, 137, 395, 421, 457, 613, 798, 846, 949, 965]
