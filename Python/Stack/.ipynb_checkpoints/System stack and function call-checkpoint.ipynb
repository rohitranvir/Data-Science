# %%
def fun2():
    print("Function2 line no 1")
def fun1():
    print("function1 line no 1")
    fun2()
    print("function1 line no 2")
def main():
    print("main function line no 1")
    fun1()
    print("main function line 2")
main()
# Out:
# main function line no 1
# function1 line no 1
# Function2 line no 1
# function1 line no 2
# main function line 2
