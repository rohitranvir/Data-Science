# %%
import statistics as st
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
dataset=[5,9,7,4,2,2,6,8]

# %%
mean=st.mean(dataset)

# %%
mean
# Out:
# 5.375

# %%
st.mode(dataset)
# Out:
# 2

# %%
st.median(dataset)
# Out:
# 5.5

# %%
df=pd.read_csv(r"D:\Data-Science\DATA Cleaning\Airbnb_Open_Data.csv")
# Out:
# C:\Users\rohit\AppData\Local\Temp\ipykernel_17124\3146916786.py:1: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv(r"D:\Data-Science\DATA Cleaning\Airbnb_Open_Data.csv")

# %%
df=sns.load_dataset('titanic'

df['age'].fillna(df['age'].mean(),inplace=True)
# Out:
#   Cell In[67], line 1
#     df=sns.load_dataset('titanic'
#                        ^
# SyntaxError: '(' was never closed

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age              0
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df['age'].mean()
# Out:
# np.float64(29.69911764705882)

# %%
mn=np.mean(df['fare'])
md=np.median(df['fare'])
mo=df['fare'].mode()

# %%
sns.histplot(x='fare',data=df,bins=[i for i in range(0,81,10)])
plt.plot([nm for i in range(0,300)],[i for i in range(0,300)],c='red',label="mean")
plt.plot([md for i in range(0,300)],[i for i in range(0,300)],c='blue',label="median")
plt.plot([mo for i in range(0,300)],[i for i in range(0,300)],c='yellow',label="mode")
plt.legend()

# %%
df['fare'].mode()
# Out:
# 0    8.05
# Name: fare, dtype: float64

# %%
df['sex'].value_counts()
# Out:
# sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
