# %%
def zig(s,n):
    st=0
    z=""
    for i in range(len(s)):
        for j in range(n):
            print(s[st])
            st+=1
    
    print(z)
s="PAYPRLISHIRING"
n=4
zig(s,n)
# Out:
# P
# A
# Y
# P
# R
# L
# I
# S
# H
# I
# R
# I
# N
# G
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[26], line 12
#      10 s="PAYPRLISHIRING"
#      11 n=4
# ---> 12 zig(s,n)
#
# Cell In[26], line 6, in zig(s, n)
#       4 for i in range(len(s)):
#       5     for j in range(n):
# ----> 6         print(s[st])
#       7         st+=1
#       9 print(z)
#
# IndexError: string index out of range

# %%
Input: s = "PAYPALISHIRING", numRows = 4
Output: "PINALSIGYAHRPI"
