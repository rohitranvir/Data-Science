# %%
def reverse(x):
    re=0
    if x<0:
        while x<0:
            if x<0:            
                t=x//10            
                re=re*10+t
                x=x//10
            else:
                t=x//10
                re=re*10+t
                x=x//10
    else:
        while x>0:
            if x<0:            
                t=x//10            
                re=re*10+t
                x=x//10
            else:
                t=x//10
                re=re*10+t
                x=x//10
    return re
x=123
reverse(x)
