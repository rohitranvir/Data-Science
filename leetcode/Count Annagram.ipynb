# %%
Output: [["bat"],["nat","tan"],["ate","eat","tea"]]

# %%
def anna(strs):
    strs.sort()
    print(strs)   

strs=["eat","tea","tan","ate","nat","bat"]
anna(strs)
# Out:
# ['ate', 'bat', 'eat', 'nat', 'tan', 'tea']
