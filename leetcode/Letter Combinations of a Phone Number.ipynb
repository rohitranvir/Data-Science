# %%
def letterCombinations(dig):    
    dic={
        '2':["a","b","c"],
        '3':["d","e","f"],
        '4':["g","h","i"],
        '5':["j","k","l"],
        '6':["m","n","o"],
        '7':["p","q","r","s"],
        '8':["t","u","v"],
        '9':["w","x","y","z"]
    }
    # dic2={}
    # while d>0:
    #     t=d%10
    #     for i in range(len(dic)):
    #         if t==dic[i]:
    #             dic2[]
    #     d=d//10
    res=[""]
    for d in dig:
        new=[]
        for i in res:
            for j in dic[d]:
                new.append(j+i)
        res=new
    return res
    
letterCombinations("23")
# Out:
# ['da', 'ea', 'fa', 'db', 'eb', 'fb', 'dc', 'ec', 'fc']
