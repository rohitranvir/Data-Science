# %%
class Solution(object):
    def spiralOrder(sel,matrix):
        rowb=0
        rowe=len(matrix)
        colb=0
        cole=len(matrix[0])
        res=[]
        while rowe>rowb and cole>colb:
            for i in range(colb,cole):
                res.append(matrix[rowb][i])
            for j in range(rowb+1,rowe-1):
                res.append(matrix[j][cole-1])
            if rowe!=rowb+1:
                for i in range(cole-1,colb-1,-1):
                    res.append(matrix[rowe-1][i])
            if colb != cole-1:
                for  j in range(rowe-2,rowb,-1):
                    res.append(matrix[j][colb])
            rowb+=1
            rowe-=1
            colb+=1
            cole-=1
        return res
s=Solution()    
matrix = [[2,5,8],
          [4,0,-1]
         ]
s.spiralOrder(matrix)
# Output: [1,2,3,6,9,8,7,4,5]
# Out:
# [2, 5, 8, -1, 0, 4]

# %%
class Solution(object):
    def spiralOrder(self,m):
        
        rowb=0
        rowe=len(m)
        colb=0
        cole=len(m[0])
        res=[]
        while rowe>rowb and cole>colb:
            for i in range(colb,cole):
                res.append(m[rowb][i])
            for j in range(rowb+1,rowe-1):
                res.append(m[j][cole-1])
            if rowe != rowb+1:
                for i in range(cole-1,colb-1,-1):
                    res.append(m[rowe-1][i])
            if cole != colb+1:
                for j in range(rowe-2,rowb,-1):
                    res.append(m[j][colb])
            rowb+=1
            rowe-=1
            colb+=1
            cole-=1
    
        return res
matrix = [[2,5,8],
          [4,0,-1]
         ]
s=Solution()
s.spiralOrder(matrix)
# Out:
# [2, 5, 8, -1, 0, 4]
