# %%
def spiralOrder(m):
    re=[]
    for i in range(len(m)):        
        for j in range(len(m[0])):
                        
        print()
matrix = [[1,2,3],[4,5,6],[7,8,9]]
spiralOrder(matrix)
# Output: [1,2,3,6,9,8,7,4,5]
# Out:
# 1 2 3
# 4 5 6
# 7 8 9
