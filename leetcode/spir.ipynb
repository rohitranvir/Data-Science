# %%
def spi(m):
    rowb=0
    rowe=len(m)
    colb=0
    cole=len(m)
    res=[]
    while rowb<rowe and colb<cole:
        for i in range(colb,cole):
            res.append(m[rowb][i])
        for j in range(rowb+1,rowe-1):
            res.append(m[j][cole-1])
       if rowe!= rowb+1

    
    
        rowb+=1
        rowe-=1
        colb+=1
        cole-=1
    print(res)  
    
m = [     [1,2,3],
          [4,5,6],
          [7,8,9] 
    ]

spi(m)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[22], line 28
#      21     print(res)
#      23 m = [     [1,2,3],
#      24           [4,5,6],
#      25           [7,8,9]
#      26     ]
# ---> 28 spi(m)
#
# Cell In[22], line 13, in spi(m)
#      11     res.append(m[j][cole-1])
#      12 for k in range(cole,colb,-1):
# ---> 13     res.append(m[k][rowe-1])
#      14 # for i in range(cole,)
#      17 rowb+=1
#
# IndexError: list index out of range

# %%
def spi(m):
    l=0
    r=len(m[0])-1
    t=0
    b=len(m[0])-1
    res=[]
    while l<=r and t<=b:
        for i in range(l,r+1):
            res.append(m[t][i])
        for i in range(t,b+1):
            res.append(m[i][r])
        if l<=r:
            for i in  range(r,l-1,-1):
                res.append(m[b][i])
        if t<=b:
            for i in range(b,t-1,-1):
                res.append(m[i][l])
    
    
        l+=1
        r-=1
        t+=1
        b-=1
    print(res)  
    
m = [     [1,2,3],
          [4,5,6],
          [7,8,9] 
    ]

spi(m)
# Out:
# [1, 2, 3, 3, 6, 9, 9, 8, 7, 7, 4, 1, 5, 5, 5, 5]

# %%
def spi(m):
    l=0
    r=len(m)-1
    t=0
    b=len(m[0])-1
    res=[]
    while l<=r and t<=b:
        for i in range(l,r+1):
            res.append(m[t][i])
        t+=1
        for j in range(t,b):
            res.append(m[t][i])
        b-=1
        for i in range(r,l):
            res.append(m[r][i])
    
    
        
    print(res)  
    
m = [     [1,2,3],
          [4,5,6],
          [7,8,9] 
    ]

spi(m)
# Out:
# [1, 2, 3, 6, 4, 5, 6]
